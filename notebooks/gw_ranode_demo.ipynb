# %% [markdown]
# # R-Anode Gravitational Wave Demo

# %% [markdown]
# Generate toy gravitational wave background and signal events
#
# Preprocess and split the data into sidebands (control) and signal regions
#
# Train the background density estimator (normalizing flow)
#
# Train the residual signal flow with a fixed signal fraction hypothesis
#
# Evaluate the learned anomaly score on a held-out sample
#
#
# All heavy Luigi/Law orchestration is skipped so the core R-Anode logic can be inspected interactively.

# %%
import os
import sys
import copy
import json
import pathlib
import numpy as np
import pandas as pd
import torch
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# ensure project root (with 'config/' and 'src/') is on sys.path
project_root = pathlib.Path.cwd().resolve()
if not (project_root / "config").exists():
    candidate = project_root.parent
    if (candidate / "config").exists():
        project_root = candidate
if (project_root / "config").exists() and str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print(f"Using project root: {project_root}")

from config import configs
from src.data_prep.gw_processing import process_gw_backgrounds, process_gw_signals, gw_background_split
from src.data_prep.utils import preprocess_params_fit, logit_transform, standardize, inverse_transform
from src.models.model_B import DensityEstimator, anode
from src.models.model_S import flows_model_RQS, r_anode_mass_joint_untransformed
from scipy.stats import rv_histogram

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
if device.type == "mps":
    torch.set_default_dtype(torch.float32)
torch.set_default_dtype(torch.float32)

torch.manual_seed(42)
# Out:
# Using project root: /Users/krishwu/code/ranode
# Using device: mps
# Using device: mps

# %%
SIGNAL_AMPLITUDE = 120.0  # tweak amplitude to study sensitivity

raw_bkg = process_gw_backgrounds()
raw_sig = process_gw_signals(amplitude=SIGNAL_AMPLITUDE)

def combine_signal_with_background(background: np.ndarray, signal: np.ndarray, scale: float = 1.0) -> np.ndarray:
    if background.shape != signal.shape:
        raise ValueError("Signal and background must share identical shape")
    combined = background.copy()
    if not np.allclose(background[:, 0], signal[:, 0], atol=1e-8):
        raise ValueError("Time grids for signal and background do not align")
    combined[:, 1] = background[:, 1] + scale * signal[:, 1]
    combined[:, 2] = background[:, 2] + scale * signal[:, 2]
    combined[:, 3] = combined[:, 1] + combined[:, 2]
    combined[:, 4] = combined[:, 1] - combined[:, 2]
    combined[:, -1] = 1.0
    return combined

combined_signal_raw = combine_signal_with_background(raw_bkg, raw_sig)
assert np.allclose(combined_signal_raw[:, 0], raw_bkg[:, 0])
assert np.allclose(combined_signal_raw[:, 1] - raw_bkg[:, 1], raw_sig[:, 1])
assert np.allclose(combined_signal_raw[:, 2] - raw_bkg[:, 2], raw_sig[:, 2])
assert np.allclose(combined_signal_raw[:, 3], combined_signal_raw[:, 1] + combined_signal_raw[:, 2])
assert np.allclose(combined_signal_raw[:, 4], combined_signal_raw[:, 1] - combined_signal_raw[:, 2])
print("Verified: signal is added sample-wise to the background")

print(f"Background shape: {raw_bkg.shape}")
print(f"Signal template shape: {raw_sig.shape}")
print(f"Signal+background combined shape: {combined_signal_raw.shape}")
print("Columns: [time, H, L, H+L, H-L, label]")
# Out:
# Verified: signal is added sample-wise to the background
# Background shape: (300, 6)
# Signal template shape: (300, 6)
# Signal+background combined shape: (300, 6)
# Columns: [time, H, L, H+L, H-L, label]

# %%
# --- split background into signal/control regions and fit preprocessing ---
SR_bkg_raw, CR_bkg_raw = gw_background_split(raw_bkg, resample_seed=42)
# I am instead basing the preprocessing params on the signal region. IMPORTANT NOTE for KRISH
# pre_params = preprocess_params_fit(CR_bkg_raw)
SR_sig_raw, CR_sig_raw = gw_background_split(combined_signal_raw, resample_seed=42)
pre_params = preprocess_params_fit(SR_sig_raw)
feature_min = pre_params["min"]
feature_max = pre_params["max"]
feature_range = feature_max - feature_min
buffer = np.maximum(feature_range * 0.1, 1e-3)
pre_params["min"] = feature_min - buffer
pre_params["max"] = feature_max + buffer
print("Pre_params:", pre_params)

def transform_with_params(data, params, clip_eps=1e-6):
    feature_min = params["min"]
    feature_max = params["max"]
    feature_mean = params["mean"]
    feature_std = params["std"]

    denom = feature_max - feature_min
    denom = np.where(denom == 0, 1e-6, denom)
    x = data[:, 1:-1]
    x_norm = (x - feature_min) / denom
    x_norm = np.clip(x_norm, clip_eps, 1 - clip_eps)
    logit = np.log(x_norm / (1 - x_norm))
    mask = np.isfinite(logit).all(axis=1)

    transformed = np.hstack([data[:, 0:1], logit, data[:, -1:]])[mask]
    transformed[:, 1:-1] = standardize(transformed[:, 1:-1], feature_mean, feature_std)
    return transformed, data[mask]

CR_processed, CR_aligned_raw = transform_with_params(CR_bkg_raw, pre_params)
SR_bkg_processed, SR_bkg_aligned_raw = transform_with_params(SR_bkg_raw, pre_params)
SR_sig_processed, SR_sig_aligned_raw = transform_with_params(SR_sig_raw, pre_params)

print(f"Control-region processed shape: {CR_processed.shape}")
print(f"Signal-region background shape: {SR_bkg_processed.shape}")
print(f"Signal-region injected signal shape: {SR_sig_processed.shape}")

# Build background mass/time PDF for later mixing
hist_counts, hist_bins = np.histogram(SR_bkg_aligned_raw[:, 0], bins=40, density=True)
mass_density = rv_histogram((hist_counts, hist_bins))

plt.clf()
# plt.scatter(SR_bkg_raw[:, 0], SR_bkg_raw[:, 1], label='Signal Region Background Time Distribution')
# plt.scatter(CR_bkg_raw[:, 0], CR_bkg_raw[:, 1], label='Control Region Background Time Distribution')
plt.scatter(SR_bkg_processed[:, 0], SR_bkg_processed[:, 1], label='Processed Signal Region Background Time Distribution')
plt.scatter(SR_sig_processed[:, 0], SR_sig_processed[:, 1], label='Processed Signal+Background Time Distribution')
# plt.scatter(CR_sig_raw[:, 0], CR_sig_raw[:, 1], label='Signal Region Raw Signal+Background Time Distribution')
plt.scatter(CR_processed[:, 0], CR_processed[:, 1], label='Processed Control Region Background Time Distribution')
plt.xlabel('Time (s)')
plt.ylabel('Strain')
plt.legend()
plt.title('Gravitational Wave Data Processing')
plt.show()
# Out:
# GW Background split: Inner=150, Outer=150
# GW Background split: Inner=150, Outer=150
# Pre_params: {'min': array([-3.10082333, -3.13834761, -4.2637758 , -4.00807251]), 'max': array([2.94814795, 2.91042119, 4.66201858, 4.4286601 ]), 'mean': array([ 0.07681177,  0.10696633, -0.11499027, -0.13769871]), 'std': array([0.76844602, 0.78165893, 0.68882885, 0.77172112])}
# Control-region processed shape: (150, 6)
# Signal-region background shape: (150, 6)
# Signal-region injected signal shape: (150, 6)

# %%
plt.clf()
plt.hist(SR_bkg_processed[:, 1], bins=40, alpha=0.5, label='Signal Region Background Time Histogram')
plt.hist(CR_processed[:, 1], bins=40, alpha=0.5, label='Control Region Background Time Histogram')
plt.hist(SR_sig_processed[:, 1], bins=40, alpha=0.5, label='Signal+Background Time Histogram')
plt.xlabel('Strain')
plt.ylabel('Density')
plt.legend()
plt.title('Strain Distribution Comparison')
plt.show()

# %%
# --- train the background normalizing flow on CR data ---
CR_train, CR_val = train_test_split(CR_processed, test_size=0.25, random_state=42, shuffle=True)

train_tensor = torch.from_numpy(CR_train.astype("float32")).to(device)
val_tensor = torch.from_numpy(CR_val.astype("float32")).to(device)

train_loader = DataLoader(TensorDataset(train_tensor), batch_size=512, shuffle=True)
val_loader = DataLoader(TensorDataset(val_tensor), batch_size=1024, shuffle=False)

config_path = project_root / "src" / "models" / "DE_MAF_model.yml"
model_B = DensityEstimator(str(config_path), eval_mode=False, device=device)

bkg_train_losses = []
bkg_val_losses = []
best_state = None
best_val = float("inf")
patience = 0
PATIENCE_LIMIT = 5
EPOCHS_BKG = 200
# Out:
# DensityEstimator has 274800 parameters

# %%
#Background training
def trainBackground():
    # modify notebook-level variables rather than creating locals
    global best_val, best_state, patience, bkg_train_losses, bkg_val_losses
    for epoch in range(1, EPOCHS_BKG + 1):
        train_loss = anode(model_B.model, train_loader, model_B.optimizer, params=None, device=device, mode="train")
        val_loss = anode(model_B.model, val_loader, model_B.optimizer, params=None, device=device, mode="val")
        bkg_train_losses.append(float(train_loss))
        bkg_val_losses.append(float(val_loss))
        print(f"[Bkg] Epoch {epoch:02d} | train: {train_loss:.4f} | val: {val_loss:.4f}")
        if val_loss < best_val - 1e-4:
            best_val = val_loss
            best_state = copy.deepcopy({k: v.cpu() for k, v in model_B.model.state_dict().items()})
            patience = 0
        else:
            patience += 1
            if patience >= PATIENCE_LIMIT:
                print("Stopping early (background model)")
                break

    if best_state is not None:
        model_B.model.load_state_dict(best_state)
    model_B.model.to(device)
    model_B.model.eval()

trainBackground()
# Out:
# setting batch norm layers to eval mode
# [Bkg] Epoch 01 | train: 123.7108 | val: 118.4805
# setting batch norm layers to eval mode
# [Bkg] Epoch 02 | train: 116.4822 | val: 109.6790
# setting batch norm layers to eval mode
# [Bkg] Epoch 03 | train: 107.7886 | val: 104.2757
# setting batch norm layers to eval mode
# [Bkg] Epoch 04 | train: 102.5068 | val: 96.4041
# setting batch norm layers to eval mode
# [Bkg] Epoch 05 | train: 94.6901 | val: 91.3592
# setting batch norm layers to eval mode
# [Bkg] Epoch 06 | train: 89.7648 | val: 85.6822
# setting batch norm layers to eval mode
# [Bkg] Epoch 04 | train: 102.5068 | val: 96.4041
# setting batch norm layers to eval mode
# [Bkg] Epoch 05 | train: 94.6901 | val: 91.3592
# setting batch norm layers to eval mode
# [Bkg] Epoch 06 | train: 89.7648 | val: 85.6822
# setting batch norm layers to eval mode
# [Bkg] Epoch 07 | train: 84.2030 | val: 78.7048
# setting batch norm layers to eval mode
# [Bkg] Epoch 08 | train: 77.2025 | val: 75.8640
# setting batch norm layers to eval mode
# [Bkg] Epoch 09 | train: 74.3146 | val: 71.7340
# setting batch norm layers to eval mode
# [Bkg] Epoch 07 | train: 84.2030 | val: 78.7048
# setting batch norm layers to eval mode
# [Bkg] Epoch 08 | train: 77.2025 | val: 75.8640
# setting batch norm layers to eval mode
# [Bkg] Epoch 09 | train: 74.3146 | val: 71.7340
# setting batch norm layers to eval mode
# [Bkg] Epoch 10 | train: 70.2303 | val: 65.9234
# setting batch norm layers to eval mode
# [Bkg] Epoch 11 | train: 64.5576 | val: 65.9066
# setting batch norm layers to eval mode
# [Bkg] Epoch 12 | train: 64.6238 | val: 65.6709
# setting batch norm layers to eval mode
# [Bkg] Epoch 10 | train: 70.2303 | val: 65.9234
# setting batch norm layers to eval mode
# [Bkg] Epoch 11 | train: 64.5576 | val: 65.9066
# setting batch norm layers to eval mode
# [Bkg] Epoch 12 | train: 64.6238 | val: 65.6709
# setting batch norm layers to eval mode
# [Bkg] Epoch 13 | train: 64.2485 | val: 63.5005
# setting batch norm layers to eval mode
# [Bkg] Epoch 14 | train: 62.0720 | val: 60.4976
# setting batch norm layers to eval mode
# [Bkg] Epoch 15 | train: 59.1010 | val: 57.6619
# setting batch norm layers to eval mode
# [Bkg] Epoch 13 | train: 64.2485 | val: 63.5005
# setting batch norm layers to eval mode
# [Bkg] Epoch 14 | train: 62.0720 | val: 60.4976
# setting batch norm layers to eval mode
# [Bkg] Epoch 15 | train: 59.1010 | val: 57.6619
# setting batch norm layers to eval mode
# [Bkg] Epoch 16 | train: 56.3012 | val: 56.0853
# setting batch norm layers to eval mode
# [Bkg] Epoch 17 | train: 54.7614 | val: 53.8296
# setting batch norm layers to eval mode
# [Bkg] Epoch 18 | train: 52.5420 | val: 50.6425
# setting batch norm layers to eval mode
# [Bkg] Epoch 16 | train: 56.3012 | val: 56.0853
# setting batch norm layers to eval mode
# [Bkg] Epoch 17 | train: 54.7614 | val: 53.8296
# setting batch norm layers to eval mode
# [Bkg] Epoch 18 | train: 52.5420 | val: 50.6425
# setting batch norm layers to eval mode
# [Bkg] Epoch 19 | train: 49.4143 | val: 47.4989
# setting batch norm layers to eval mode
# [Bkg] Epoch 20 | train: 46.4069 | val: 42.9501
# setting batch norm layers to eval mode
# [Bkg] Epoch 21 | train: 42.0600 | val: 40.0219
# setting batch norm layers to eval mode
# [Bkg] Epoch 19 | train: 49.4143 | val: 47.4989
# setting batch norm layers to eval mode
# [Bkg] Epoch 20 | train: 46.4069 | val: 42.9501
# setting batch norm layers to eval mode
# [Bkg] Epoch 21 | train: 42.0600 | val: 40.0219
# setting batch norm layers to eval mode
# [Bkg] Epoch 22 | train: 39.5748 | val: 37.3585
# setting batch norm layers to eval mode
# [Bkg] Epoch 23 | train: 36.7109 | val: 35.0466
# setting batch norm layers to eval mode
# [Bkg] Epoch 24 | train: 34.5780 | val: 33.0244
# setting batch norm layers to eval mode
# [Bkg] Epoch 22 | train: 39.5748 | val: 37.3585
# setting batch norm layers to eval mode
# [Bkg] Epoch 23 | train: 36.7109 | val: 35.0466
# setting batch norm layers to eval mode
# [Bkg] Epoch 24 | train: 34.5780 | val: 33.0244
# setting batch norm layers to eval mode
# [Bkg] Epoch 25 | train: 32.4423 | val: 30.5588
# setting batch norm layers to eval mode
# [Bkg] Epoch 26 | train: 29.9338 | val: 29.3044
# setting batch norm layers to eval mode
# [Bkg] Epoch 27 | train: 28.8472 | val: 26.6415
# setting batch norm layers to eval mode
# [Bkg] Epoch 25 | train: 32.4423 | val: 30.5588
# setting batch norm layers to eval mode
# [Bkg] Epoch 26 | train: 29.9338 | val: 29.3044
# setting batch norm layers to eval mode
# [Bkg] Epoch 27 | train: 28.8472 | val: 26.6415
# setting batch norm layers to eval mode
# [Bkg] Epoch 28 | train: 26.2740 | val: 24.7819
# setting batch norm layers to eval mode
# [Bkg] Epoch 29 | train: 24.2837 | val: 26.1042
# setting batch norm layers to eval mode
# [Bkg] Epoch 30 | train: 25.4825 | val: 24.5155
# setting batch norm layers to eval mode
# setting batch norm layers to eval mode
# [Bkg] Epoch 28 | train: 26.2740 | val: 24.7819
# setting batch norm layers to eval mode
# [Bkg] Epoch 29 | train: 24.2837 | val: 26.1042
# setting batch norm layers to eval mode
# [Bkg] Epoch 30 | train: 25.4825 | val: 24.5155
# setting batch norm layers to eval mode
# [Bkg] Epoch 31 | train: 24.0261 | val: 20.8487
# setting batch norm layers to eval mode
# [Bkg] Epoch 32 | train: 20.7911 | val: 19.4436
# setting batch norm layers to eval mode
# [Bkg] Epoch 33 | train: 18.8676 | val: 19.0940
# [Bkg] Epoch 31 | train: 24.0261 | val: 20.8487
# setting batch norm layers to eval mode
# [Bkg] Epoch 32 | train: 20.7911 | val: 19.4436
# setting batch norm layers to eval mode
# [Bkg] Epoch 33 | train: 18.8676 | val: 19.0940
# setting batch norm layers to eval mode
# [Bkg] Epoch 34 | train: 18.4752 | val: 15.2989
# setting batch norm layers to eval mode
# [Bkg] Epoch 35 | train: 15.2066 | val: 16.0936
# setting batch norm layers to eval mode
# [Bkg] Epoch 36 | train: 16.1815 | val: 15.1515
# setting batch norm layers to eval mode
# setting batch norm layers to eval mode
# [Bkg] Epoch 34 | train: 18.4752 | val: 15.2989
# setting batch norm layers to eval mode
# [Bkg] Epoch 35 | train: 15.2066 | val: 16.0936
# setting batch norm layers to eval mode
# [Bkg] Epoch 36 | train: 16.1815 | val: 15.1515
# setting batch norm layers to eval mode
# [Bkg] Epoch 37 | train: 15.2121 | val: 14.5999
# setting batch norm layers to eval mode
# [Bkg] Epoch 38 | train: 14.2524 | val: 12.5825
# setting batch norm layers to eval mode
# [Bkg] Epoch 39 | train: 12.2157 | val: 11.8646
# [Bkg] Epoch 37 | train: 15.2121 | val: 14.5999
# setting batch norm layers to eval mode
# [Bkg] Epoch 38 | train: 14.2524 | val: 12.5825
# setting batch norm layers to eval mode
# [Bkg] Epoch 39 | train: 12.2157 | val: 11.8646
# setting batch norm layers to eval mode
# [Bkg] Epoch 40 | train: 11.9030 | val: 10.8395
# setting batch norm layers to eval mode
# [Bkg] Epoch 41 | train: 11.0299 | val: 10.4371
# setting batch norm layers to eval mode
# [Bkg] Epoch 42 | train: 10.7988 | val: 10.7258
# setting batch norm layers to eval mode
# setting batch norm layers to eval mode
# [Bkg] Epoch 40 | train: 11.9030 | val: 10.8395
# setting batch norm layers to eval mode
# [Bkg] Epoch 41 | train: 11.0299 | val: 10.4371
# setting batch norm layers to eval mode
# [Bkg] Epoch 42 | train: 10.7988 | val: 10.7258
# setting batch norm layers to eval mode
# [Bkg] Epoch 43 | train: 10.7545 | val: 10.0219
# setting batch norm layers to eval mode
# [Bkg] Epoch 44 | train: 9.8782 | val: 10.2990
# setting batch norm layers to eval mode
# [Bkg] Epoch 45 | train: 10.2318 | val: 9.6486
# setting batch norm layers to eval mode
# [Bkg] Epoch 46 | train: 10.1288 | val: 9.0724
# [Bkg] Epoch 43 | train: 10.7545 | val: 10.0219
# setting batch norm layers to eval mode
# [Bkg] Epoch 44 | train: 9.8782 | val: 10.2990
# setting batch norm layers to eval mode
# [Bkg] Epoch 45 | train: 10.2318 | val: 9.6486
# setting batch norm layers to eval mode
# [Bkg] Epoch 46 | train: 10.1288 | val: 9.0724
# setting batch norm layers to eval mode
# [Bkg] Epoch 47 | train: 9.5080 | val: 8.8187
# setting batch norm layers to eval mode
# [Bkg] Epoch 48 | train: 8.8521 | val: 8.7199
# setting batch norm layers to eval mode
# [Bkg] Epoch 49 | train: 8.6118 | val: 8.3485
# setting batch norm layers to eval mode
# [Bkg] Epoch 47 | train: 9.5080 | val: 8.8187
# setting batch norm layers to eval mode
# [Bkg] Epoch 48 | train: 8.8521 | val: 8.7199
# setting batch norm layers to eval mode
# [Bkg] Epoch 49 | train: 8.6118 | val: 8.3485
# setting batch norm layers to eval mode
# [Bkg] Epoch 50 | train: 8.2668 | val: 7.9589
# setting batch norm layers to eval mode
# [Bkg] Epoch 51 | train: 7.9847 | val: 7.5740
# setting batch norm layers to eval mode
# [Bkg] Epoch 52 | train: 7.5093 | val: 7.4142
# setting batch norm layers to eval mode
# [Bkg] Epoch 50 | train: 8.2668 | val: 7.9589
# setting batch norm layers to eval mode
# [Bkg] Epoch 51 | train: 7.9847 | val: 7.5740
# setting batch norm layers to eval mode
# [Bkg] Epoch 52 | train: 7.5093 | val: 7.4142
# setting batch norm layers to eval mode
# [Bkg] Epoch 53 | train: 7.1732 | val: 7.0614
# setting batch norm layers to eval mode
# [Bkg] Epoch 54 | train: 6.8688 | val: 6.8604
# setting batch norm layers to eval mode
# [Bkg] Epoch 55 | train: 6.5261 | val: 6.7115
# setting batch norm layers to eval mode
# [Bkg] Epoch 53 | train: 7.1732 | val: 7.0614
# setting batch norm layers to eval mode
# [Bkg] Epoch 54 | train: 6.8688 | val: 6.8604
# setting batch norm layers to eval mode
# [Bkg] Epoch 55 | train: 6.5261 | val: 6.7115
# setting batch norm layers to eval mode
# [Bkg] Epoch 56 | train: 6.2334 | val: 6.3747
# setting batch norm layers to eval mode
# [Bkg] Epoch 57 | train: 5.9133 | val: 6.0134
# setting batch norm layers to eval mode
# [Bkg] Epoch 58 | train: 5.3954 | val: 5.3209
# setting batch norm layers to eval mode
# [Bkg] Epoch 56 | train: 6.2334 | val: 6.3747
# setting batch norm layers to eval mode
# [Bkg] Epoch 57 | train: 5.9133 | val: 6.0134
# setting batch norm layers to eval mode
# [Bkg] Epoch 58 | train: 5.3954 | val: 5.3209
# setting batch norm layers to eval mode
# [Bkg] Epoch 59 | train: 4.8961 | val: 5.3347
# setting batch norm layers to eval mode
# [Bkg] Epoch 60 | train: 4.7266 | val: 5.2307
# setting batch norm layers to eval mode
# [Bkg] Epoch 61 | train: 4.5602 | val: 4.4869
# setting batch norm layers to eval mode
# setting batch norm layers to eval mode
# [Bkg] Epoch 59 | train: 4.8961 | val: 5.3347
# setting batch norm layers to eval mode
# [Bkg] Epoch 60 | train: 4.7266 | val: 5.2307
# setting batch norm layers to eval mode
# [Bkg] Epoch 61 | train: 4.5602 | val: 4.4869
# setting batch norm layers to eval mode
# [Bkg] Epoch 62 | train: 4.0931 | val: 4.5713
# setting batch norm layers to eval mode
# [Bkg] Epoch 63 | train: 3.9492 | val: 4.3957
# setting batch norm layers to eval mode
# [Bkg] Epoch 64 | train: 3.7295 | val: 4.0643
# setting batch norm layers to eval mode
# [Bkg] Epoch 65 | train: 3.5415 | val: 3.8273
# [Bkg] Epoch 62 | train: 4.0931 | val: 4.5713
# setting batch norm layers to eval mode
# [Bkg] Epoch 63 | train: 3.9492 | val: 4.3957
# setting batch norm layers to eval mode
# [Bkg] Epoch 64 | train: 3.7295 | val: 4.0643
# setting batch norm layers to eval mode
# [Bkg] Epoch 65 | train: 3.5415 | val: 3.8273
# setting batch norm layers to eval mode
# [Bkg] Epoch 66 | train: 3.0861 | val: 3.9519
# setting batch norm layers to eval mode
# [Bkg] Epoch 67 | train: 3.2029 | val: 3.4377
# setting batch norm layers to eval mode
# [Bkg] Epoch 68 | train: 2.7479 | val: 3.1962
# setting batch norm layers to eval mode
# setting batch norm layers to eval mode
# [Bkg] Epoch 66 | train: 3.0861 | val: 3.9519
# setting batch norm layers to eval mode
# [Bkg] Epoch 67 | train: 3.2029 | val: 3.4377
# setting batch norm layers to eval mode
# [Bkg] Epoch 68 | train: 2.7479 | val: 3.1962
# setting batch norm layers to eval mode
# [Bkg] Epoch 69 | train: 2.7450 | val: 3.2052
# setting batch norm layers to eval mode
# [Bkg] Epoch 70 | train: 2.7788 | val: 2.8655
# setting batch norm layers to eval mode
# [Bkg] Epoch 71 | train: 2.2962 | val: 2.3330
# setting batch norm layers to eval mode
# [Bkg] Epoch 72 | train: 1.8845 | val: 2.4802
# [Bkg] Epoch 69 | train: 2.7450 | val: 3.2052
# setting batch norm layers to eval mode
# [Bkg] Epoch 70 | train: 2.7788 | val: 2.8655
# setting batch norm layers to eval mode
# [Bkg] Epoch 71 | train: 2.2962 | val: 2.3330
# setting batch norm layers to eval mode
# [Bkg] Epoch 72 | train: 1.8845 | val: 2.4802
# setting batch norm layers to eval mode
# [Bkg] Epoch 73 | train: 1.7756 | val: 2.0254
# setting batch norm layers to eval mode
# [Bkg] Epoch 74 | train: 1.4099 | val: 1.9645
# setting batch norm layers to eval mode
# [Bkg] Epoch 75 | train: 1.2542 | val: 1.4407
# setting batch norm layers to eval mode
# [Bkg] Epoch 73 | train: 1.7756 | val: 2.0254
# setting batch norm layers to eval mode
# [Bkg] Epoch 74 | train: 1.4099 | val: 1.9645
# setting batch norm layers to eval mode
# [Bkg] Epoch 75 | train: 1.2542 | val: 1.4407
# setting batch norm layers to eval mode
# [Bkg] Epoch 76 | train: 0.9490 | val: 1.4066
# setting batch norm layers to eval mode
# [Bkg] Epoch 77 | train: 0.7612 | val: 1.0979
# setting batch norm layers to eval mode
# [Bkg] Epoch 78 | train: 0.6013 | val: 0.8768
# setting batch norm layers to eval mode
# [Bkg] Epoch 76 | train: 0.9490 | val: 1.4066
# setting batch norm layers to eval mode
# [Bkg] Epoch 77 | train: 0.7612 | val: 1.0979
# setting batch norm layers to eval mode
# [Bkg] Epoch 78 | train: 0.6013 | val: 0.8768
# setting batch norm layers to eval mode
# [Bkg] Epoch 79 | train: 0.3162 | val: 1.0439
# setting batch norm layers to eval mode
# [Bkg] Epoch 80 | train: 0.1589 | val: 1.1049
# setting batch norm layers to eval mode
# [Bkg] Epoch 81 | train: 0.3415 | val: 1.0354
# setting batch norm layers to eval mode
# [Bkg] Epoch 82 | train: 0.5030 | val: 0.5444
# setting batch norm layers to eval mode
# [Bkg] Epoch 79 | train: 0.3162 | val: 1.0439
# setting batch norm layers to eval mode
# [Bkg] Epoch 80 | train: 0.1589 | val: 1.1049
# setting batch norm layers to eval mode
# [Bkg] Epoch 81 | train: 0.3415 | val: 1.0354
# setting batch norm layers to eval mode
# [Bkg] Epoch 82 | train: 0.5030 | val: 0.5444
# setting batch norm layers to eval mode
# [Bkg] Epoch 83 | train: -0.3048 | val: 0.2197
# setting batch norm layers to eval mode
# [Bkg] Epoch 84 | train: -0.6399 | val: -0.1388
# setting batch norm layers to eval mode
# [Bkg] Epoch 85 | train: -0.9318 | val: -0.5741
# setting batch norm layers to eval mode
# [Bkg] Epoch 83 | train: -0.3048 | val: 0.2197
# setting batch norm layers to eval mode
# [Bkg] Epoch 84 | train: -0.6399 | val: -0.1388
# setting batch norm layers to eval mode
# [Bkg] Epoch 85 | train: -0.9318 | val: -0.5741
# setting batch norm layers to eval mode
# [Bkg] Epoch 86 | train: -1.0776 | val: -0.4906
# setting batch norm layers to eval mode
# [Bkg] Epoch 87 | train: -0.7778 | val: -0.4136
# setting batch norm layers to eval mode
# [Bkg] Epoch 88 | train: -0.9421 | val: -0.4236
# setting batch norm layers to eval mode
# [Bkg] Epoch 89 | train: -1.0640 | val: -0.7581
# setting batch norm layers to eval mode
# [Bkg] Epoch 86 | train: -1.0776 | val: -0.4906
# setting batch norm layers to eval mode
# [Bkg] Epoch 87 | train: -0.7778 | val: -0.4136
# setting batch norm layers to eval mode
# [Bkg] Epoch 88 | train: -0.9421 | val: -0.4236
# setting batch norm layers to eval mode
# [Bkg] Epoch 89 | train: -1.0640 | val: -0.7581
# setting batch norm layers to eval mode
# [Bkg] Epoch 90 | train: -1.4224 | val: -0.7729
# setting batch norm layers to eval mode
# [Bkg] Epoch 91 | train: -1.6709 | val: -0.7979
# setting batch norm layers to eval mode
# [Bkg] Epoch 92 | train: -1.5841 | val: -0.9678
# setting batch norm layers to eval mode
# [Bkg] Epoch 90 | train: -1.4224 | val: -0.7729
# setting batch norm layers to eval mode
# [Bkg] Epoch 91 | train: -1.6709 | val: -0.7979
# setting batch norm layers to eval mode
# [Bkg] Epoch 92 | train: -1.5841 | val: -0.9678
# setting batch norm layers to eval mode
# [Bkg] Epoch 93 | train: -1.9038 | val: -1.0734
# setting batch norm layers to eval mode
# [Bkg] Epoch 94 | train: -2.1273 | val: -0.7659
# setting batch norm layers to eval mode
# [Bkg] Epoch 95 | train: -1.6614 | val: -0.6971
# setting batch norm layers to eval mode
# [Bkg] Epoch 96 | train: -1.2183 | val: -0.1185
# setting batch norm layers to eval mode
# [Bkg] Epoch 93 | train: -1.9038 | val: -1.0734
# setting batch norm layers to eval mode
# [Bkg] Epoch 94 | train: -2.1273 | val: -0.7659
# setting batch norm layers to eval mode
# [Bkg] Epoch 95 | train: -1.6614 | val: -0.6971
# setting batch norm layers to eval mode
# [Bkg] Epoch 96 | train: -1.2183 | val: -0.1185
# setting batch norm layers to eval mode
# [Bkg] Epoch 97 | train: -0.9642 | val: 0.0097
# setting batch norm layers to eval mode
# [Bkg] Epoch 98 | train: -0.7659 | val: -0.7073
# Stopping early (background model)
# setting batch norm layers to eval mode
# [Bkg] Epoch 97 | train: -0.9642 | val: 0.0097
# setting batch norm layers to eval mode
# [Bkg] Epoch 98 | train: -0.7659 | val: -0.7073
# Stopping early (background model)

# %%
# --- prepare signal-region datasets & background log probabilities ---
SR_combined_processed = np.vstack([SR_bkg_processed, SR_sig_processed])
SR_combined_raw = np.vstack([SR_bkg_aligned_raw, SR_sig_aligned_raw])

indices = np.arange(len(SR_combined_processed))
train_idx, test_idx = train_test_split(
    indices,
    test_size=0.2,
    random_state=1337,
    stratify=SR_combined_processed[:, -1],
)

SR_train_all = SR_combined_processed[train_idx]
SR_train_raw_all = SR_combined_raw[train_idx]
SR_test = SR_combined_processed[test_idx]
SR_test_raw = SR_combined_raw[test_idx]

with torch.no_grad():
    train_tensor_all = torch.from_numpy(SR_train_all.astype("float32")).to(device)
    log_B_train_all = model_B.model.log_probs(
        inputs=train_tensor_all[:, 1:-1],
        cond_inputs=train_tensor_all[:, 0:1],
    ).cpu().numpy()

    test_tensor = torch.from_numpy(SR_test.astype("float32")).to(device)
    log_B_test = model_B.model.log_probs(
        inputs=test_tensor[:, 1:-1],
        cond_inputs=test_tensor[:, 0:1],
    ).cpu().numpy()

mass_pdf_train_all = mass_density.pdf(SR_train_raw_all[:, 0])
mass_pdf_test = mass_density.pdf(SR_test_raw[:, 0])

# split train into (train, val)
inner_indices = np.arange(len(SR_train_all))
train_inner_idx, val_inner_idx = train_test_split(
    inner_indices,
    test_size=0.2,
    random_state=2024,
    stratify=SR_train_all[:, -1],
)

SR_train = SR_train_all[train_inner_idx]
SR_val = SR_train_all[val_inner_idx]
SR_train_raw = SR_train_raw_all[train_inner_idx]
SR_val_raw = SR_train_raw_all[val_inner_idx]

log_B_train = log_B_train_all[train_inner_idx]
log_B_val = log_B_train_all[val_inner_idx]

mass_pdf_train = mass_pdf_train_all[train_inner_idx]
mass_pdf_val = mass_pdf_train_all[val_inner_idx]

center_time = 0.5 * (configs.SR_MIN + configs.SR_MAX)
def shift_time(data):
    shifted = data.copy()
    shifted[:, 0] -= center_time
    return shifted

SR_train_shifted = shift_time(SR_train)
SR_val_shifted = shift_time(SR_val)
SR_test_shifted = shift_time(SR_test)
SR_sig_shifted = shift_time(SR_sig_processed)

signal_fraction = float(SR_train[:, -1].mean())
print(f"Training signal fraction w ≈ {signal_fraction:.4f}")
# Out:
# Training signal fraction w ≈ 0.5000

# %%
# --- train the residual signal flow ---
train_dataset = TensorDataset(
    torch.from_numpy(SR_train_shifted.astype("float32")).to(device),
    torch.from_numpy(log_B_train.astype("float32")).to(device),
    torch.from_numpy(mass_pdf_train.astype("float32")).to(device),
)
val_dataset = TensorDataset(
    torch.from_numpy(SR_val_shifted.astype("float32")).to(device),
    torch.from_numpy(log_B_val.astype("float32")).to(device),
    torch.from_numpy(mass_pdf_val.astype("float32")).to(device),
)

train_loader_S = DataLoader(train_dataset, batch_size=256, shuffle=True)
val_loader_S = DataLoader(val_dataset, batch_size=512, shuffle=False)

model_S = flows_model_RQS(
    num_layers=4,
    num_features=4,
    num_blocks=2,
    hidden_features=64,
    device=device,
    context_features=1,
)

optimizer_S = torch.optim.AdamW(model_S.parameters(), lr=3e-4)
scheduler_S = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer_S, T_0=10, T_mult=2)

sig_train_losses = []
sig_val_losses = []
best_state_S = None
best_val_S = float("inf")
patience_S = 0
PATIENCE_LIMIT_S = 8
EPOCHS_SIG = 200

# %%
# Signal training
def trainSignal():
    # modify notebook-level variables rather than creating locals
    global best_val_S, best_state_S, patience_S, sig_train_losses, sig_val_losses
    for epoch in range(1, EPOCHS_SIG + 1):
        train_loss = r_anode_mass_joint_untransformed(
            model_S=model_S,
            w=signal_fraction,
            optimizer=optimizer_S,
            data_loader=train_loader_S,
            device=device,
            mode="train",
            scheduler=scheduler_S,
        )
        val_loss = r_anode_mass_joint_untransformed(
            model_S=model_S,
            w=signal_fraction,
            optimizer=optimizer_S,
            data_loader=val_loader_S,
            device=device,
            mode="val",
        )
        sig_train_losses.append(float(train_loss))
        sig_val_losses.append(float(val_loss))
        print(f"[Signal] Epoch {epoch:02d} | train: {train_loss:.4f} | val: {val_loss:.4f}")
        if val_loss < best_val_S - 1e-4:
            best_val_S = val_loss
            best_state_S = copy.deepcopy({k: v.cpu() for k, v in model_S.state_dict().items()})
            patience_S = 0
        else:
            patience_S += 1
            if patience_S >= PATIENCE_LIMIT_S:
                print("Stopping early (signal model)")
                break
        scheduler_S.step()

    if best_state_S is not None:
        model_S.load_state_dict(best_state_S)
    model_S.to(device)
    model_S.eval()

trainSignal()
# Out:
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 01 | train: 6.3466 | val: 5.8654
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 02 | train: 6.1862 | val: 5.7522
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 03 | train: 6.2157 | val: 5.6909
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 04 | train: 6.1052 | val: 5.6582
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 03 | train: 6.2157 | val: 5.6909
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 04 | train: 6.1052 | val: 5.6582
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 05 | train: 6.0396 | val: 5.6387
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 06 | train: 5.9751 | val: 5.5983
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 05 | train: 6.0396 | val: 5.6387
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 06 | train: 5.9751 | val: 5.5983
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 07 | train: 5.9526 | val: 5.5701
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 08 | train: 5.8862 | val: 5.5520
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 07 | train: 5.9526 | val: 5.5701
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 08 | train: 5.8862 | val: 5.5520
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 09 | train: 5.7000 | val: 5.5388
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 10 | train: 5.7853 | val: 5.5312
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 09 | train: 5.7000 | val: 5.5388
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 10 | train: 5.7853 | val: 5.5312
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 11 | train: 5.7816 | val: 5.5221
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 12 | train: 5.7390 | val: 5.5152
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 11 | train: 5.7816 | val: 5.5221
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 12 | train: 5.7390 | val: 5.5152
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 13 | train: 5.6812 | val: 5.5094
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 14 | train: 5.7661 | val: 5.5056
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 13 | train: 5.6812 | val: 5.5094
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 14 | train: 5.7661 | val: 5.5056
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 15 | train: 5.6879 | val: 5.5008
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 16 | train: 5.7109 | val: 5.4867
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 17 | train: 5.5040 | val: 5.4717
# value of w: 0.5
# [Signal] Epoch 15 | train: 5.6879 | val: 5.5008
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 16 | train: 5.7109 | val: 5.4867
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 17 | train: 5.5040 | val: 5.4717
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 18 | train: 5.6821 | val: 5.4542
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 19 | train: 5.6198 | val: 5.4344
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 18 | train: 5.6821 | val: 5.4542
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 19 | train: 5.6198 | val: 5.4344
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 20 | train: 5.4683 | val: 5.4147
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 21 | train: 5.5513 | val: 5.3986
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 22 | train: 5.4496 | val: 5.3823
# value of w: 0.5
# [Signal] Epoch 20 | train: 5.4683 | val: 5.4147
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 21 | train: 5.5513 | val: 5.3986
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 22 | train: 5.4496 | val: 5.3823
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 23 | train: 5.3627 | val: 5.3638
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 24 | train: 5.4412 | val: 5.3472
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 23 | train: 5.3627 | val: 5.3638
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 24 | train: 5.4412 | val: 5.3472
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 25 | train: 5.4521 | val: 5.3290
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 26 | train: 5.2427 | val: 5.3100
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 25 | train: 5.4521 | val: 5.3290
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 26 | train: 5.2427 | val: 5.3100
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 27 | train: 5.2658 | val: 5.2887
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 28 | train: 5.4961 | val: 5.2719
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 27 | train: 5.2658 | val: 5.2887
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 28 | train: 5.4961 | val: 5.2719
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 29 | train: 5.3557 | val: 5.2557
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 30 | train: 5.2885 | val: 5.2398
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 31 | train: 5.2540 | val: 5.2274
# value of w: 0.5
# [Signal] Epoch 29 | train: 5.3557 | val: 5.2557
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 30 | train: 5.2885 | val: 5.2398
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 31 | train: 5.2540 | val: 5.2274
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 32 | train: 5.4368 | val: 5.2152
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 33 | train: 5.2533 | val: 5.2032
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 32 | train: 5.4368 | val: 5.2152
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 33 | train: 5.2533 | val: 5.2032
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 34 | train: 5.4172 | val: 5.1912
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 35 | train: 5.3399 | val: 5.1816
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 34 | train: 5.4172 | val: 5.1912
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 35 | train: 5.3399 | val: 5.1816
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 36 | train: 5.2723 | val: 5.1437
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 37 | train: 5.2121 | val: 5.1010
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 36 | train: 5.2723 | val: 5.1437
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 37 | train: 5.2121 | val: 5.1010
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 38 | train: 5.2268 | val: 5.0606
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 39 | train: 5.1883 | val: 5.0180
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 38 | train: 5.2268 | val: 5.0606
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 39 | train: 5.1883 | val: 5.0180
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 40 | train: 5.1384 | val: 4.9746
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 41 | train: 5.1760 | val: 4.9293
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 42 | train: 5.2246 | val: 4.8873
# value of w: 0.5
# [Signal] Epoch 40 | train: 5.1384 | val: 4.9746
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 41 | train: 5.1760 | val: 4.9293
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 42 | train: 5.2246 | val: 4.8873
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 43 | train: 5.0480 | val: 4.8439
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 44 | train: 5.1135 | val: 4.8060
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 43 | train: 5.0480 | val: 4.8439
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 44 | train: 5.1135 | val: 4.8060
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 45 | train: 4.9994 | val: 4.7734
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 46 | train: 4.9850 | val: 4.7412
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 45 | train: 4.9994 | val: 4.7734
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 46 | train: 4.9850 | val: 4.7412
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 47 | train: 4.9702 | val: 4.7119
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 48 | train: 4.9555 | val: 4.6820
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 49 | train: 4.9369 | val: 4.6517
# value of w: 0.5
# [Signal] Epoch 47 | train: 4.9702 | val: 4.7119
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 48 | train: 4.9555 | val: 4.6820
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 49 | train: 4.9369 | val: 4.6517
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 50 | train: 5.0813 | val: 4.6284
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 51 | train: 4.8253 | val: 4.6040
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 50 | train: 5.0813 | val: 4.6284
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 51 | train: 4.8253 | val: 4.6040
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 52 | train: 4.7724 | val: 4.5828
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 53 | train: 4.7742 | val: 4.5644
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 54 | train: 4.9053 | val: 4.5469
# value of w: 0.5
# [Signal] Epoch 52 | train: 4.7724 | val: 4.5828
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 53 | train: 4.7742 | val: 4.5644
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 54 | train: 4.9053 | val: 4.5469
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 55 | train: 4.6622 | val: 4.5220
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 56 | train: 4.7322 | val: 4.4962
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 55 | train: 4.6622 | val: 4.5220
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 56 | train: 4.7322 | val: 4.4962
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 57 | train: 4.7418 | val: 4.4696
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 58 | train: 4.7834 | val: 4.4520
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 59 | train: 4.7565 | val: 4.4324
# value of w: 0.5
# [Signal] Epoch 57 | train: 4.7418 | val: 4.4696
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 58 | train: 4.7834 | val: 4.4520
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 59 | train: 4.7565 | val: 4.4324
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 60 | train: 4.7556 | val: 4.4103
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 61 | train: 4.7731 | val: 4.3958
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 60 | train: 4.7556 | val: 4.4103
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 61 | train: 4.7731 | val: 4.3958
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 62 | train: 4.7822 | val: 4.3814
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 63 | train: 4.6614 | val: 4.3643
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 64 | train: 4.7262 | val: 4.3561
# value of w: 0.5
# [Signal] Epoch 62 | train: 4.7822 | val: 4.3814
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 63 | train: 4.6614 | val: 4.3643
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 64 | train: 4.7262 | val: 4.3561
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 65 | train: 4.7057 | val: 4.3441
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 66 | train: 4.6260 | val: 4.3338
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 65 | train: 4.7057 | val: 4.3441
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 66 | train: 4.6260 | val: 4.3338
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 67 | train: 4.7930 | val: 4.3236
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 68 | train: 4.8330 | val: 4.3180
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 67 | train: 4.7930 | val: 4.3236
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 68 | train: 4.8330 | val: 4.3180
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 69 | train: 4.7854 | val: 4.3139
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 70 | train: 4.6735 | val: 4.3088
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 69 | train: 4.7854 | val: 4.3139
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 70 | train: 4.6735 | val: 4.3088
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 71 | train: 4.6550 | val: 4.3049
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 72 | train: 4.6784 | val: 4.3022
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 73 | train: 4.7252 | val: 4.2968
# value of w: 0.5
# [Signal] Epoch 71 | train: 4.6550 | val: 4.3049
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 72 | train: 4.6784 | val: 4.3022
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 73 | train: 4.7252 | val: 4.2968
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 74 | train: 4.7163 | val: 4.2958
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 75 | train: 4.6415 | val: 4.2945
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 74 | train: 4.7163 | val: 4.2958
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 75 | train: 4.6415 | val: 4.2945
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 76 | train: 4.6331 | val: 4.2789
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 77 | train: 4.7323 | val: 4.2607
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 78 | train: 4.7509 | val: 4.2382
# value of w: 0.5
# [Signal] Epoch 76 | train: 4.6331 | val: 4.2789
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 77 | train: 4.7323 | val: 4.2607
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 78 | train: 4.7509 | val: 4.2382
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 79 | train: 4.5765 | val: 4.2110
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 80 | train: 4.5549 | val: 4.1872
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 79 | train: 4.5765 | val: 4.2110
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 80 | train: 4.5549 | val: 4.1872
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 81 | train: 4.4979 | val: 4.1619
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 82 | train: 4.5288 | val: 4.1374
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 83 | train: 4.4491 | val: 4.1146
# value of w: 0.5
# [Signal] Epoch 81 | train: 4.4979 | val: 4.1619
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 82 | train: 4.5288 | val: 4.1374
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 83 | train: 4.4491 | val: 4.1146
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 84 | train: 4.5223 | val: 4.0837
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 85 | train: 4.3637 | val: 4.0543
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 84 | train: 4.5223 | val: 4.0837
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 85 | train: 4.3637 | val: 4.0543
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 86 | train: 4.4758 | val: 4.0238
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 87 | train: 4.3431 | val: 3.9966
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 86 | train: 4.4758 | val: 4.0238
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 87 | train: 4.3431 | val: 3.9966
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 88 | train: 4.3575 | val: 3.9731
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 89 | train: 4.2568 | val: 3.9513
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 88 | train: 4.3575 | val: 3.9731
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 89 | train: 4.2568 | val: 3.9513
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 90 | train: 4.2312 | val: 3.9314
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 91 | train: 4.2535 | val: 3.9111
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 92 | train: 4.2157 | val: 3.8923
# value of w: 0.5
# [Signal] Epoch 90 | train: 4.2312 | val: 3.9314
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 91 | train: 4.2535 | val: 3.9111
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 92 | train: 4.2157 | val: 3.8923
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 93 | train: 4.2811 | val: 3.8801
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 94 | train: 4.1416 | val: 3.8592
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 93 | train: 4.2811 | val: 3.8801
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 94 | train: 4.1416 | val: 3.8592
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 95 | train: 4.1467 | val: 3.8428
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 96 | train: 4.0964 | val: 3.8299
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 95 | train: 4.1467 | val: 3.8428
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 96 | train: 4.0964 | val: 3.8299
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 97 | train: 4.1625 | val: 3.8137
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 98 | train: 4.1082 | val: 3.7939
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 99 | train: 4.1996 | val: 3.7794
# value of w: 0.5
# [Signal] Epoch 97 | train: 4.1625 | val: 3.8137
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 98 | train: 4.1082 | val: 3.7939
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 99 | train: 4.1996 | val: 3.7794
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 100 | train: 4.1079 | val: 3.7679
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 101 | train: 4.0463 | val: 3.7567
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 100 | train: 4.1079 | val: 3.7679
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 101 | train: 4.0463 | val: 3.7567
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 102 | train: 4.0215 | val: 3.7425
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 103 | train: 4.0593 | val: 3.7246
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 104 | train: 4.2099 | val: 3.7076
# value of w: 0.5
# [Signal] Epoch 102 | train: 4.0215 | val: 3.7425
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 103 | train: 4.0593 | val: 3.7246
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 104 | train: 4.2099 | val: 3.7076
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 105 | train: 4.0059 | val: 3.6888
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 106 | train: 3.8253 | val: 3.6674
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 105 | train: 4.0059 | val: 3.6888
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 106 | train: 3.8253 | val: 3.6674
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 107 | train: 4.0925 | val: 3.6519
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 108 | train: 3.8891 | val: 3.6356
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 109 | train: 3.8520 | val: 3.6224
# value of w: 0.5
# [Signal] Epoch 107 | train: 4.0925 | val: 3.6519
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 108 | train: 3.8891 | val: 3.6356
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 109 | train: 3.8520 | val: 3.6224
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 110 | train: 3.9469 | val: 3.6110
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 111 | train: 3.9726 | val: 3.6032
# value of w: 0.5
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 110 | train: 3.9469 | val: 3.6110
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 111 | train: 3.9726 | val: 3.6032
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 112 | train: 3.8283 | val: 3.6036
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 113 | train: 4.0691 | val: 3.6034
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 114 | train: 3.8900 | val: 3.6082
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 112 | train: 3.8283 | val: 3.6036
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 113 | train: 4.0691 | val: 3.6034
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 114 | train: 3.8900 | val: 3.6082
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 115 | train: 3.8840 | val: 3.6108
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 116 | train: 3.7566 | val: 3.6127
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 117 | train: 3.9517 | val: 3.6105
# value of w: 0.5
# [Signal] Epoch 115 | train: 3.8840 | val: 3.6108
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 116 | train: 3.7566 | val: 3.6127
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 117 | train: 3.9517 | val: 3.6105
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 118 | train: 3.9356 | val: 3.6147
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 119 | train: 3.7766 | val: 3.6154
# Stopping early (signal model)
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 118 | train: 3.9356 | val: 3.6147
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 119 | train: 3.7766 | val: 3.6154
# Stopping early (signal model)

# %%
# Plot training curves for background and signal models
fig, ax = plt.subplots(1, 2, figsize=(12, 4), sharex=True)
ax[0].plot(bkg_train_losses, label="Train")
ax[0].plot(bkg_val_losses, label="Validation")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].set_title("Background Flow Training")
ax[0].legend()

ax[1].plot(sig_train_losses, label="Train")
ax[1].plot(sig_val_losses, label="Validation")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Loss")
ax[1].set_title("Signal Flow Training")
ax[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpreting the density plot**
#
# The histogram shows the distribution of the likelihood ratio for signal (orange) and background (blue) events. Values greater than 1 mean the signal model assigns higher density than the background model for that event, but background events can still produce \(R>1\) because the two densities overlap in feature space. What matters is the relative separation of the two curves: the farther the orange curve sits to the right of the blue one, the easier it is to choose a threshold on \(R\) that keeps signal while rejecting background. The ROC curve below quantifies that separation across all thresholds.

# %%
# --- evaluate anomaly scores on held-out sample ---
with torch.no_grad():
    test_shifted_tensor = torch.from_numpy(SR_test_shifted.astype("float32")).to(device)
    sig_log_prob = model_S.log_prob(
        inputs=test_shifted_tensor[:, 1:-1],
        context=test_shifted_tensor[:, 0:1],
    ).cpu().numpy()

sig_prob = np.exp(sig_log_prob)
bg_prob = np.exp(log_B_test.flatten()) * mass_pdf_test
ratio = sig_prob / (bg_prob + 1e-12)

labels = SR_test[:, -1]

plt.figure(figsize=(7, 4))
plt.hist(ratio[labels == 0], bins=40, density=True, histtype='step', linewidth=2, color='tab:blue', label='Background')
plt.hist(ratio[labels == 1], bins=40, density=True, histtype='stepfilled', alpha=0.4, color='tab:orange', label='Signal')
plt.yscale("log")
plt.xlabel("R(x) = p_sig / p_bg")
plt.ylabel("Density")
plt.legend()
plt.title("Residual ANODE Anomaly Score")
plt.show()

signal_eff = (ratio[labels == 1] > 1.0).mean()
background_eff = (ratio[labels == 0] > 1.0).mean()
print(f"Signal efficiency at R>1: {signal_eff:.3f}")
print(f"Background efficiency at R>1: {background_eff:.3f}")

score_df = pd.DataFrame(
    {
        "time_ms": SR_test[:, 0],
        "label": labels,
        "sig_prob": sig_prob,
        "bg_prob": bg_prob,
        "anomaly_ratio": ratio,
    }
)
csv_path = project_root / "notebooks" / "anomaly_scores.csv"
score_df.to_csv(csv_path, index=False)
print(f"Saved anomaly scores to {csv_path}")
# Out:
# Signal efficiency at R>1: 0.867
# Background efficiency at R>1: 0.633
# Saved anomaly scores to /Users/krishwu/code/ranode/notebooks/anomaly_scores.csv

# %%
fpr, tpr, thresholds = roc_curve(labels, ratio)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], 'k--', alpha=0.6)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for R-Anode Score")
plt.legend(loc="lower right")
plt.grid(True, alpha=0.2)
plt.show()

# %%
# --- visualize strains vs time and distributions for data vs learned models ---
def sample_subset(data: np.ndarray, max_points: int = 600, rng: np.random.Generator = np.random.default_rng()):
    if len(data) <= max_points:
        return data
    idx = rng.choice(len(data), size=max_points, replace=False)
    return data[idx]

with torch.no_grad():
    cond_inputs = torch.from_numpy(SR_bkg_aligned_raw[:, 0].astype("float32")).reshape(-1, 1).to(device)
    bg_generated = model_B.model.sample(num_samples=cond_inputs.shape[0], cond_inputs=cond_inputs).cpu().numpy()
    sig_context = torch.from_numpy(SR_sig_shifted[:, 0:1].astype("float32")).to(device)
    generated = []
    for ctx in torch.split(sig_context, 1, dim=0):
        sample = model_S.sample(num_samples=1, context=ctx).cpu().numpy()
        if sample.ndim == 3:
            sample = sample[0, 0]
        elif sample.ndim == 2:
            sample = sample[0]
        generated.append(np.asarray(sample))
    sig_generated_features = np.stack(generated, axis=0)

bg_generated_full = np.concatenate([SR_bkg_aligned_raw[:, 0:1], bg_generated, np.zeros((bg_generated.shape[0], 1))], axis=1)
bg_generated_raw = inverse_transform(bg_generated_full, pre_params)

sig_time = sig_context.cpu().numpy() + center_time
sig_generated_features = np.atleast_2d(sig_generated_features)
sig_generated_processed = np.concatenate([sig_time, sig_generated_features, np.ones((sig_generated_features.shape[0], 1))], axis=1)
sig_generated_raw = inverse_transform(sig_generated_processed, pre_params)

plot_sets = {
    "Background Data": SR_bkg_aligned_raw,
    "Signal Data": SR_sig_aligned_raw,
    "Background Model": bg_generated_raw,
    "Signal Model": sig_generated_raw,
}

feature_names = [
    ("H_strain", 1),
    ("L_strain", 2),
    ("H+L", 3),
    ("H-L", 4),
 ]

rng = np.random.default_rng(2025)
for name, idx in feature_names:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    all_values = []
    for label, dataset in plot_sets.items():
        all_values.append(dataset[:, idx])
        subset = sample_subset(dataset, max_points=600, rng=rng)
        axes[0].scatter(subset[:, 0], subset[:, idx], label=label, s=10, alpha=0.5)
    axes[0].set_xlabel("Time [ms]")
    axes[0].set_ylabel(name)
    axes[0].set_title(f"{name} vs Time")
    axes[0].legend()

    values_concat = np.concatenate(all_values)
    vmin = np.quantile(values_concat, 0.01)
    vmax = np.quantile(values_concat, 0.99)
    bins = np.linspace(vmin, vmax, 60)

    for label, dataset in plot_sets.items():
        axes[1].hist(dataset[:, idx], bins=bins, histtype="step", density=True, label=label)

    axes[1].set_xlabel(name)
    axes[1].set_ylabel("Density")
    axes[1].set_title(f"{name} Distribution")
    axes[1].legend()
    plt.tight_layout()
    plt.show()
