# %% [markdown]
# # R-Anode Gravitational Wave Demo

# %% [markdown]
# Generate toy gravitational wave background and signal events
#
# Preprocess and split the data into sidebands (control) and signal regions
#
# Train the background density estimator (normalizing flow)
#
# Train the residual signal flow with a fixed signal fraction hypothesis
#
# Evaluate the learned anomaly score on a held-out sample
#
#
# All heavy Luigi/Law orchestration is skipped so the core R-Anode logic can be inspected interactively.

# %%
import os
import sys
import copy
import json
import pathlib
import numpy as np
import pandas as pd
import torch
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# ensure project root (with 'config/' and 'src/') is on sys.path
project_root = pathlib.Path.cwd().resolve()
if not (project_root / "config").exists():
    candidate = project_root.parent
    if (candidate / "config").exists():
        project_root = candidate
if (project_root / "config").exists() and str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print(f"Using project root: {project_root}")

from config import configs
from src.data_prep.gw_processing import process_gw_backgrounds, process_gw_signals, gw_background_split
from src.data_prep.utils import preprocess_params_fit, logit_transform, standardize, inverse_transform
from src.models.model_B import DensityEstimator, anode
from src.models.model_S import flows_model_RQS, r_anode_mass_joint_untransformed
from scipy.stats import rv_histogram

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
if device.type == "mps":
    torch.set_default_dtype(torch.float32)
torch.set_default_dtype(torch.float32)

torch.manual_seed(42)
# Out:
# Using project root: /Users/krishwu/code/ranode
# Using device: mps

# %%
SIGNAL_AMPLITUDE = 120.0  # tweak amplitude to study sensitivity

raw_bkg = process_gw_backgrounds()
raw_sig = process_gw_signals(amplitude=SIGNAL_AMPLITUDE)

def combine_signal_with_background(background: np.ndarray, signal: np.ndarray, scale: float = 1.0) -> np.ndarray:
    if background.shape != signal.shape:
        raise ValueError("Signal and background must share identical shape")
    combined = background.copy()
    if not np.allclose(background[:, 0], signal[:, 0], atol=1e-8):
        raise ValueError("Time grids for signal and background do not align")
    combined[:, 1] = background[:, 1] + scale * signal[:, 1]
    combined[:, 2] = background[:, 2] + scale * signal[:, 2]
    combined[:, 3] = combined[:, 1] + combined[:, 2]
    combined[:, 4] = combined[:, 1] - combined[:, 2]
    combined[:, -1] = 1.0
    return combined

combined_signal_raw = combine_signal_with_background(raw_bkg, raw_sig)
assert np.allclose(combined_signal_raw[:, 0], raw_bkg[:, 0])
assert np.allclose(combined_signal_raw[:, 1] - raw_bkg[:, 1], raw_sig[:, 1])
assert np.allclose(combined_signal_raw[:, 2] - raw_bkg[:, 2], raw_sig[:, 2])
assert np.allclose(combined_signal_raw[:, 3], combined_signal_raw[:, 1] + combined_signal_raw[:, 2])
assert np.allclose(combined_signal_raw[:, 4], combined_signal_raw[:, 1] - combined_signal_raw[:, 2])
print("Verified: signal is added sample-wise to the background")

print(f"Background shape: {raw_bkg.shape}")
print(f"Signal template shape: {raw_sig.shape}")
print(f"Signal+background combined shape: {combined_signal_raw.shape}")
print("Columns: [time, H, L, H+L, H-L, label]")
# Out:
# Verified: signal is added sample-wise to the background
# Background shape: (300, 6)
# Signal template shape: (300, 6)
# Signal+background combined shape: (300, 6)
# Columns: [time, H, L, H+L, H-L, label]

# %%
# --- split background into signal/control regions and fit preprocessing ---
SR_bkg_raw, CR_bkg_raw = gw_background_split(raw_bkg, resample_seed=42)
# I am instead basing the preprocessing params on the signal region. IMPORTANT NOTE for KRISH
# pre_params = preprocess_params_fit(CR_bkg_raw)
SR_sig_raw, CR_sig_raw = gw_background_split(combined_signal_raw, resample_seed=42)
pre_params = preprocess_params_fit(SR_sig_raw)
feature_min = pre_params["min"]
feature_max = pre_params["max"]
feature_range = feature_max - feature_min
buffer = np.maximum(feature_range * 0.1, 1e-3)
pre_params["min"] = feature_min - buffer
pre_params["max"] = feature_max + buffer
print("Pre_params:", pre_params)

def transform_with_params(data, params, clip_eps=1e-6):
    feature_min = params["min"]
    feature_max = params["max"]
    feature_mean = params["mean"]
    feature_std = params["std"]

    denom = feature_max - feature_min
    denom = np.where(denom == 0, 1e-6, denom)
    x = data[:, 1:-1]
    x_norm = (x - feature_min) / denom
    x_norm = np.clip(x_norm, clip_eps, 1 - clip_eps)
    logit = np.log(x_norm / (1 - x_norm))
    mask = np.isfinite(logit).all(axis=1)

    transformed = np.hstack([data[:, 0:1], logit, data[:, -1:]])[mask]
    transformed[:, 1:-1] = standardize(transformed[:, 1:-1], feature_mean, feature_std)
    return transformed, data[mask]

CR_processed, CR_aligned_raw = transform_with_params(CR_bkg_raw, pre_params)
SR_bkg_processed, SR_bkg_aligned_raw = transform_with_params(SR_bkg_raw, pre_params)
SR_sig_processed, SR_sig_aligned_raw = transform_with_params(SR_sig_raw, pre_params)

print(f"Control-region processed shape: {CR_processed.shape}")
print(f"Signal-region background shape: {SR_bkg_processed.shape}")
print(f"Signal-region injected signal shape: {SR_sig_processed.shape}")

# Build background mass/time PDF for later mixing
hist_counts, hist_bins = np.histogram(SR_bkg_aligned_raw[:, 0], bins=40, density=True)
mass_density = rv_histogram((hist_counts, hist_bins))

plt.clf()
# plt.scatter(SR_bkg_raw[:, 0], SR_bkg_raw[:, 1], label='Signal Region Background Time Distribution')
# plt.scatter(CR_bkg_raw[:, 0], CR_bkg_raw[:, 1], label='Control Region Background Time Distribution')
plt.scatter(SR_bkg_processed[:, 0], SR_bkg_processed[:, 1], label='Processed Signal Region Background Time Distribution')
plt.scatter(SR_sig_processed[:, 0], SR_sig_processed[:, 1], label='Processed Signal+Background Time Distribution')
# plt.scatter(CR_sig_raw[:, 0], CR_sig_raw[:, 1], label='Signal Region Raw Signal+Background Time Distribution')
plt.scatter(CR_processed[:, 0], CR_processed[:, 1], label='Processed Control Region Background Time Distribution')
plt.xlabel('Time (s)')
plt.ylabel('Strain')
plt.legend()
plt.title('Gravitational Wave Data Processing')
plt.show()
# Out:
# GW Background split: Inner=150, Outer=150
# GW Background split: Inner=150, Outer=150
# Pre_params: {'min': array([-2.96589548, -3.12306857, -3.88466298, -3.92394029]), 'max': array([2.99936373, 2.96166265, 4.7045525 , 4.71979938]), 'mean': array([ 0.02735962,  0.11400298, -0.26173503, -0.28619658]), 'std': array([0.9956153 , 0.78419998, 0.89505843, 0.87226902])}
# Control-region processed shape: (150, 6)
# Signal-region background shape: (150, 6)
# Signal-region injected signal shape: (150, 6)

# %%
plt.clf()
plt.hist(SR_bkg_processed[:, 1], bins=40, alpha=0.5, label='Signal Region Background Time Histogram')
plt.hist(CR_processed[:, 1], bins=40, alpha=0.5, label='Control Region Background Time Histogram')
plt.hist(SR_sig_processed[:, 1], bins=40, alpha=0.5, label='Signal+Background Time Histogram')
plt.xlabel('Strain')
plt.ylabel('Density')
plt.legend()
plt.title('Strain Distribution Comparison')
plt.show()

# %%
# --- train the background normalizing flow on CR data ---
CR_train, CR_val = train_test_split(CR_processed, test_size=0.25, random_state=42, shuffle=True)

train_tensor = torch.from_numpy(CR_train.astype("float32")).to(device)
val_tensor = torch.from_numpy(CR_val.astype("float32")).to(device)

train_loader = DataLoader(TensorDataset(train_tensor), batch_size=512, shuffle=True)
val_loader = DataLoader(TensorDataset(val_tensor), batch_size=1024, shuffle=False)

config_path = project_root / "src" / "models" / "DE_MAF_model.yml"
model_B = DensityEstimator(str(config_path), eval_mode=False, device=device)

bkg_train_losses = []
bkg_val_losses = []
best_state = None
best_val = float("inf")
patience = 0
PATIENCE_LIMIT = 5
EPOCHS_BKG = 200
# Out:
# DensityEstimator has 274800 parameters
# setting batch norm layers to eval mode
# [Bkg] Epoch 01 | train: 124.0242 | val: 118.7888
# setting batch norm layers to eval mode
# [Bkg] Epoch 02 | train: 116.8077 | val: 110.0126
# setting batch norm layers to eval mode
# [Bkg] Epoch 03 | train: 108.1388 | val: 104.6672
# setting batch norm layers to eval mode
# [Bkg] Epoch 04 | train: 102.9143 | val: 97.0573
# setting batch norm layers to eval mode
# [Bkg] Epoch 05 | train: 95.3598 | val: 89.8234
# setting batch norm layers to eval mode
# [Bkg] Epoch 06 | train: 88.2387 | val: 84.1842
# setting batch norm layers to eval mode
# [Bkg] Epoch 07 | train: 82.6907 | val: 78.9599
# setting batch norm layers to eval mode
# [Bkg] Epoch 08 | train: 77.4126 | val: 76.1288
# setting batch norm layers to eval mode
# [Bkg] Epoch 09 | train: 74.5588 | val: 71.8385
# setting batch norm layers to eval mode
# [Bkg] Epoch 10 | train: 70.3888 | val: 65.1838
# setting batch norm layers to eval mode
# [Bkg] Epoch 11 | train: 63.8293 | val: 64.8205
# setting batch norm layers to eval mode
# [Bkg] Epoch 12 | train: 63.5289 | val: 61.2419
# setting batch norm layers to eval mode
# [Bkg] Epoch 13 | train: 59.8947 | val: 59.1283
# setting batch norm layers to eval mode
# [Bkg] Epoch 14 | train: 57.9702 | val: 56.6144
# setting batch norm layers to eval mode
# [Bkg] Epoch 15 | train: 55.3936 | val: 54.4404
# setting batch norm layers to eval mode
# [Bkg] Epoch 16 | train: 53.2319 | val: 52.7513
# setting batch norm layers to eval mode
# [Bkg] Epoch 17 | train: 51.5338 | val: 50.0121
# setting batch norm layers to eval mode
# [Bkg] Epoch 18 | train: 48.8290 | val: 47.9821
# setting batch norm layers to eval mode
# [Bkg] Epoch 19 | train: 46.8798 | val: 45.0914
# setting batch norm layers to eval mode
# [Bkg] Epoch 20 | train: 44.2581 | val: 41.3997
# setting batch norm layers to eval mode
# [Bkg] Epoch 21 | train: 40.8939 | val: 40.4407
# setting batch norm layers to eval mode
# [Bkg] Epoch 22 | train: 39.7639 | val: 37.9998
# setting batch norm layers to eval mode
# [Bkg] Epoch 23 | train: 37.3302 | val: 37.0746
# setting batch norm layers to eval mode
# [Bkg] Epoch 24 | train: 36.4215 | val: 34.7141
# setting batch norm layers to eval mode
# [Bkg] Epoch 25 | train: 34.0150 | val: 31.2279
# setting batch norm layers to eval mode
# [Bkg] Epoch 26 | train: 30.4838 | val: 30.3565
# setting batch norm layers to eval mode
# [Bkg] Epoch 27 | train: 29.6636 | val: 27.9868
# setting batch norm layers to eval mode
# [Bkg] Epoch 28 | train: 27.3592 | val: 27.3994
# setting batch norm layers to eval mode
# [Bkg] Epoch 29 | train: 26.8181 | val: 25.7636
# setting batch norm layers to eval mode
# [Bkg] Epoch 30 | train: 25.3794 | val: 22.6779
# setting batch norm layers to eval mode
# [Bkg] Epoch 31 | train: 22.7062 | val: 19.5214
# setting batch norm layers to eval mode
# [Bkg] Epoch 32 | train: 19.6489 | val: 19.4089
# setting batch norm layers to eval mode
# [Bkg] Epoch 33 | train: 18.9202 | val: 18.8353
# setting batch norm layers to eval mode
# [Bkg] Epoch 34 | train: 18.4264 | val: 17.3221
# setting batch norm layers to eval mode
# [Bkg] Epoch 35 | train: 17.4317 | val: 15.0165
# setting batch norm layers to eval mode
# [Bkg] Epoch 36 | train: 15.2529 | val: 13.7914
# setting batch norm layers to eval mode
# [Bkg] Epoch 37 | train: 14.0138 | val: 15.6177
# setting batch norm layers to eval mode
# [Bkg] Epoch 38 | train: 15.9794 | val: 14.3630
# setting batch norm layers to eval mode
# [Bkg] Epoch 39 | train: 14.5704 | val: 12.8436
# setting batch norm layers to eval mode
# [Bkg] Epoch 40 | train: 13.0186 | val: 12.9723
# setting batch norm layers to eval mode
# [Bkg] Epoch 41 | train: 13.0197 | val: 12.0308
# setting batch norm layers to eval mode
# [Bkg] Epoch 42 | train: 12.5116 | val: 9.8441
# setting batch norm layers to eval mode
# [Bkg] Epoch 43 | train: 10.3800 | val: 10.5920
# setting batch norm layers to eval mode
# [Bkg] Epoch 44 | train: 10.4170 | val: 9.8951
# setting batch norm layers to eval mode
# [Bkg] Epoch 45 | train: 10.0508 | val: 9.2676
# setting batch norm layers to eval mode
# [Bkg] Epoch 46 | train: 9.5273 | val: 8.3703
# setting batch norm layers to eval mode
# [Bkg] Epoch 47 | train: 8.6647 | val: 8.5787
# setting batch norm layers to eval mode
# [Bkg] Epoch 48 | train: 8.8072 | val: 8.3147
# setting batch norm layers to eval mode
# [Bkg] Epoch 49 | train: 8.6223 | val: 7.6155
# setting batch norm layers to eval mode
# [Bkg] Epoch 50 | train: 7.7945 | val: 7.7322
# setting batch norm layers to eval mode
# [Bkg] Epoch 51 | train: 7.7501 | val: 7.0258
# setting batch norm layers to eval mode
# [Bkg] Epoch 52 | train: 7.0886 | val: 7.0724
# setting batch norm layers to eval mode
# [Bkg] Epoch 53 | train: 6.8074 | val: 7.0642
# setting batch norm layers to eval mode
# [Bkg] Epoch 54 | train: 6.5438 | val: 5.8056
# setting batch norm layers to eval mode
# [Bkg] Epoch 55 | train: 6.0003 | val: 5.7882
# setting batch norm layers to eval mode
# [Bkg] Epoch 56 | train: 5.7757 | val: 5.2709
# setting batch norm layers to eval mode
# [Bkg] Epoch 57 | train: 5.0312 | val: 5.5155
# setting batch norm layers to eval mode
# [Bkg] Epoch 58 | train: 5.1621 | val: 5.2011
# setting batch norm layers to eval mode
# [Bkg] Epoch 59 | train: 4.6324 | val: 5.5466
# setting batch norm layers to eval mode
# [Bkg] Epoch 60 | train: 4.7623 | val: 4.8913
# setting batch norm layers to eval mode
# [Bkg] Epoch 61 | train: 3.9785 | val: 4.4960
# setting batch norm layers to eval mode
# [Bkg] Epoch 62 | train: 3.8978 | val: 4.0667
# setting batch norm layers to eval mode
# [Bkg] Epoch 63 | train: 3.7708 | val: 3.6803
# setting batch norm layers to eval mode
# [Bkg] Epoch 64 | train: 3.1649 | val: 3.4576
# setting batch norm layers to eval mode
# [Bkg] Epoch 65 | train: 3.2059 | val: 3.3212
# setting batch norm layers to eval mode
# [Bkg] Epoch 66 | train: 2.9116 | val: 3.0129
# setting batch norm layers to eval mode
# [Bkg] Epoch 67 | train: 2.4830 | val: 3.1188
# setting batch norm layers to eval mode
# [Bkg] Epoch 68 | train: 2.5938 | val: 3.0467
# setting batch norm layers to eval mode
# [Bkg] Epoch 69 | train: 2.5119 | val: 2.2519
# setting batch norm layers to eval mode
# [Bkg] Epoch 70 | train: 2.2303 | val: 2.3831
# setting batch norm layers to eval mode
# [Bkg] Epoch 71 | train: 1.7359 | val: 2.5197
# setting batch norm layers to eval mode
# [Bkg] Epoch 72 | train: 1.7866 | val: 1.8147
# setting batch norm layers to eval mode
# [Bkg] Epoch 73 | train: 1.3360 | val: 1.4808
# setting batch norm layers to eval mode
# [Bkg] Epoch 74 | train: 1.3268 | val: 1.1801
# setting batch norm layers to eval mode
# [Bkg] Epoch 75 | train: 1.0457 | val: 1.5741
# setting batch norm layers to eval mode
# [Bkg] Epoch 76 | train: 0.9949 | val: 0.9598
# setting batch norm layers to eval mode
# [Bkg] Epoch 77 | train: 0.8310 | val: 0.9553
# setting batch norm layers to eval mode
# [Bkg] Epoch 78 | train: 0.8615 | val: 0.3633
# setting batch norm layers to eval mode
# [Bkg] Epoch 79 | train: 0.1560 | val: 0.2959
# setting batch norm layers to eval mode
# [Bkg] Epoch 80 | train: 0.0322 | val: -0.1269
# setting batch norm layers to eval mode
# [Bkg] Epoch 81 | train: -0.4161 | val: 0.4291
# setting batch norm layers to eval mode
# [Bkg] Epoch 82 | train: 0.0930 | val: 0.0785
# setting batch norm layers to eval mode
# [Bkg] Epoch 83 | train: -0.0878 | val: 0.5450
# setting batch norm layers to eval mode
# [Bkg] Epoch 84 | train: 0.2365 | val: -0.0458
# setting batch norm layers to eval mode
# [Bkg] Epoch 85 | train: 0.0216 | val: 0.0993
# Stopping early (background model)
# FlowSequential(
#   (0): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (1): BatchNormFlow()
#   (2): Reverse()
#   (3): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (4): BatchNormFlow()
#   (5): Reverse()
#   (6): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (7): BatchNormFlow()
#   (8): Reverse()
#   (9): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (10): BatchNormFlow()
#   (11): Reverse()
#   (12): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (13): BatchNormFlow()
#   (14): Reverse()
#   (15): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (16): BatchNormFlow()
#   (17): Reverse()
#   (18): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (19): BatchNormFlow()
#   (20): Reverse()
#   (21): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (22): BatchNormFlow()
#   (23): Reverse()
#   (24): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (25): BatchNormFlow()
#   (26): Reverse()
#   (27): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (28): BatchNormFlow()
#   (29): Reverse()
#   (30): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (31): BatchNormFlow()
#   (32): Reverse()
#   (33): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (34): BatchNormFlow()
#   (35): Reverse()
#   (36): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (37): BatchNormFlow()
#   (38): Reverse()
#   (39): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (40): BatchNormFlow()
#   (41): Reverse()
#   (42): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (43): BatchNormFlow()
#   (44): Reverse()
# )

# %%
#Background training
def trainBackground():
    # modify notebook-level variables rather than creating locals
    global best_val, best_state, patience, bkg_train_losses, bkg_val_losses
    for epoch in range(1, EPOCHS_BKG + 1):
        train_loss = anode(model_B.model, train_loader, model_B.optimizer, params=None, device=device, mode="train")
        val_loss = anode(model_B.model, val_loader, model_B.optimizer, params=None, device=device, mode="val")
        bkg_train_losses.append(float(train_loss))
        bkg_val_losses.append(float(val_loss))
        print(f"[Bkg] Epoch {epoch:02d} | train: {train_loss:.4f} | val: {val_loss:.4f}")
        if val_loss < best_val - 1e-4:
            best_val = val_loss
            best_state = copy.deepcopy({k: v.cpu() for k, v in model_B.model.state_dict().items()})
            patience = 0
        else:
            patience += 1
            if patience >= PATIENCE_LIMIT:
                print("Stopping early (background model)")
                break

    if best_state is not None:
        model_B.model.load_state_dict(best_state)
    model_B.model.to(device)
    model_B.model.eval()

trainBackground()
# Out:
# setting batch norm layers to eval mode
# [Bkg] Epoch 01 | train: -0.9985 | val: -0.8808
# setting batch norm layers to eval mode
# [Bkg] Epoch 02 | train: -0.7589 | val: -0.5190
# setting batch norm layers to eval mode
# [Bkg] Epoch 03 | train: -0.7284 | val: -0.6698
# setting batch norm layers to eval mode
# [Bkg] Epoch 04 | train: -0.8305 | val: -0.5717
# setting batch norm layers to eval mode
# [Bkg] Epoch 05 | train: -1.1837 | val: -0.7405
# setting batch norm layers to eval mode
# [Bkg] Epoch 06 | train: -1.2905 | val: -1.0461
# setting batch norm layers to eval mode
# [Bkg] Epoch 07 | train: -0.9102 | val: -0.2236
# [Bkg] Epoch 04 | train: -0.8305 | val: -0.5717
# setting batch norm layers to eval mode
# [Bkg] Epoch 05 | train: -1.1837 | val: -0.7405
# setting batch norm layers to eval mode
# [Bkg] Epoch 06 | train: -1.2905 | val: -1.0461
# setting batch norm layers to eval mode
# [Bkg] Epoch 07 | train: -0.9102 | val: -0.2236
# setting batch norm layers to eval mode
# [Bkg] Epoch 08 | train: -1.0848 | val: -1.1655
# setting batch norm layers to eval mode
# [Bkg] Epoch 09 | train: -1.7167 | val: -1.1084
# setting batch norm layers to eval mode
# [Bkg] Epoch 10 | train: -0.8652 | val: -0.6808
# setting batch norm layers to eval mode
# [Bkg] Epoch 11 | train: -0.6595 | val: -1.3977
# setting batch norm layers to eval mode
# [Bkg] Epoch 08 | train: -1.0848 | val: -1.1655
# setting batch norm layers to eval mode
# [Bkg] Epoch 09 | train: -1.7167 | val: -1.1084
# setting batch norm layers to eval mode
# [Bkg] Epoch 10 | train: -0.8652 | val: -0.6808
# setting batch norm layers to eval mode
# [Bkg] Epoch 11 | train: -0.6595 | val: -1.3977
# setting batch norm layers to eval mode
# [Bkg] Epoch 12 | train: -1.2880 | val: -1.3978
# setting batch norm layers to eval mode
# [Bkg] Epoch 13 | train: -1.4994 | val: -0.6859
# setting batch norm layers to eval mode
# [Bkg] Epoch 14 | train: -1.3559 | val: -1.4084
# setting batch norm layers to eval mode
# setting batch norm layers to eval mode
# [Bkg] Epoch 12 | train: -1.2880 | val: -1.3978
# setting batch norm layers to eval mode
# [Bkg] Epoch 13 | train: -1.4994 | val: -0.6859
# setting batch norm layers to eval mode
# [Bkg] Epoch 14 | train: -1.3559 | val: -1.4084
# setting batch norm layers to eval mode
# [Bkg] Epoch 15 | train: -1.5680 | val: -1.7899
# setting batch norm layers to eval mode
# [Bkg] Epoch 16 | train: -1.7704 | val: -1.6180
# setting batch norm layers to eval mode
# [Bkg] Epoch 17 | train: -1.5319 | val: -2.2102
# [Bkg] Epoch 15 | train: -1.5680 | val: -1.7899
# setting batch norm layers to eval mode
# [Bkg] Epoch 16 | train: -1.7704 | val: -1.6180
# setting batch norm layers to eval mode
# [Bkg] Epoch 17 | train: -1.5319 | val: -2.2102
# setting batch norm layers to eval mode
# [Bkg] Epoch 18 | train: -2.1840 | val: -2.0251
# setting batch norm layers to eval mode
# [Bkg] Epoch 19 | train: -2.2436 | val: -1.1800
# setting batch norm layers to eval mode
# [Bkg] Epoch 20 | train: -1.1254 | val: -1.6087
# setting batch norm layers to eval mode
# [Bkg] Epoch 21 | train: -1.7027 | val: -0.9756
# setting batch norm layers to eval mode
# setting batch norm layers to eval mode
# [Bkg] Epoch 18 | train: -2.1840 | val: -2.0251
# setting batch norm layers to eval mode
# [Bkg] Epoch 19 | train: -2.2436 | val: -1.1800
# setting batch norm layers to eval mode
# [Bkg] Epoch 20 | train: -1.1254 | val: -1.6087
# setting batch norm layers to eval mode
# [Bkg] Epoch 21 | train: -1.7027 | val: -0.9756
# setting batch norm layers to eval mode
# [Bkg] Epoch 22 | train: -1.2987 | val: -0.4762
# Stopping early (background model)
# [Bkg] Epoch 22 | train: -1.2987 | val: -0.4762
# Stopping early (background model)

# %%
# --- prepare signal-region datasets & background log probabilities ---
SR_combined_processed = np.vstack([SR_bkg_processed, SR_sig_processed])
SR_combined_raw = np.vstack([SR_bkg_aligned_raw, SR_sig_aligned_raw])

indices = np.arange(len(SR_combined_processed))
train_idx, test_idx = train_test_split(
    indices,
    test_size=0.2,
    random_state=1337,
    stratify=SR_combined_processed[:, -1],
)

SR_train_all = SR_combined_processed[train_idx]
SR_train_raw_all = SR_combined_raw[train_idx]
SR_test = SR_combined_processed[test_idx]
SR_test_raw = SR_combined_raw[test_idx]

with torch.no_grad():
    train_tensor_all = torch.from_numpy(SR_train_all.astype("float32")).to(device)
    log_B_train_all = model_B.model.log_probs(
        inputs=train_tensor_all[:, 1:-1],
        cond_inputs=train_tensor_all[:, 0:1],
    ).cpu().numpy()

    test_tensor = torch.from_numpy(SR_test.astype("float32")).to(device)
    log_B_test = model_B.model.log_probs(
        inputs=test_tensor[:, 1:-1],
        cond_inputs=test_tensor[:, 0:1],
    ).cpu().numpy()

mass_pdf_train_all = mass_density.pdf(SR_train_raw_all[:, 0])
mass_pdf_test = mass_density.pdf(SR_test_raw[:, 0])

# split train into (train, val)
inner_indices = np.arange(len(SR_train_all))
train_inner_idx, val_inner_idx = train_test_split(
    inner_indices,
    test_size=0.2,
    random_state=2024,
    stratify=SR_train_all[:, -1],
)

SR_train = SR_train_all[train_inner_idx]
SR_val = SR_train_all[val_inner_idx]
SR_train_raw = SR_train_raw_all[train_inner_idx]
SR_val_raw = SR_train_raw_all[val_inner_idx]

log_B_train = log_B_train_all[train_inner_idx]
log_B_val = log_B_train_all[val_inner_idx]

mass_pdf_train = mass_pdf_train_all[train_inner_idx]
mass_pdf_val = mass_pdf_train_all[val_inner_idx]

center_time = 0.5 * (configs.SR_MIN + configs.SR_MAX)
def shift_time(data):
    shifted = data.copy()
    shifted[:, 0] -= center_time
    return shifted

SR_train_shifted = shift_time(SR_train)
SR_val_shifted = shift_time(SR_val)
SR_test_shifted = shift_time(SR_test)
SR_sig_shifted = shift_time(SR_sig_processed)

signal_fraction = float(SR_train[:, -1].mean())
print(f"Training signal fraction w ≈ {signal_fraction:.4f}")
# Out:
# Training signal fraction w ≈ 0.5000

# %%
# --- train the residual signal flow ---
train_dataset = TensorDataset(
    torch.from_numpy(SR_train_shifted.astype("float32")).to(device),
    torch.from_numpy(log_B_train.astype("float32")).to(device),
    torch.from_numpy(mass_pdf_train.astype("float32")).to(device),
)
val_dataset = TensorDataset(
    torch.from_numpy(SR_val_shifted.astype("float32")).to(device),
    torch.from_numpy(log_B_val.astype("float32")).to(device),
    torch.from_numpy(mass_pdf_val.astype("float32")).to(device),
)

train_loader_S = DataLoader(train_dataset, batch_size=256, shuffle=True)
val_loader_S = DataLoader(val_dataset, batch_size=512, shuffle=False)

model_S = flows_model_RQS(
    num_layers=4,
    num_features=4,
    num_blocks=2,
    hidden_features=64,
    device=device,
    context_features=1,
)

optimizer_S = torch.optim.AdamW(model_S.parameters(), lr=3e-4)
scheduler_S = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer_S, T_0=10, T_mult=2)

sig_train_losses = []
sig_val_losses = []
best_state_S = None
best_val_S = float("inf")
patience_S = 0
PATIENCE_LIMIT_S = 8
EPOCHS_SIG = 200
# Out:
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 01 | train: 7.6844 | val: 6.3536
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 02 | train: 7.3884 | val: 6.2011
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 03 | train: 7.0703 | val: 6.1434
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 04 | train: 7.0443 | val: 6.1308
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 05 | train: 6.6281 | val: 6.1467
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 06 | train: 6.9407 | val: 6.1122
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 07 | train: 6.6009 | val: 6.0715
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 08 | train: 6.5032 | val: 6.0256
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 09 | train: 6.4416 | val: 5.9696
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 10 | train: 6.1728 | val: 5.9279
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 11 | train: 5.8937 | val: 5.9022
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 12 | train: 5.9839 | val: 5.8767
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 13 | train: 5.8940 | val: 5.8545
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 14 | train: 6.0042 | val: 5.8417
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 15 | train: 6.2171 | val: 5.8323
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 16 | train: 6.2124 | val: 5.7872
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 17 | train: 5.9264 | val: 5.7375
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 18 | train: 5.9820 | val: 5.6851
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 19 | train: 5.6362 | val: 5.6359
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 20 | train: 5.6246 | val: 5.5856
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 21 | train: 5.6337 | val: 5.5334
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 22 | train: 5.6687 | val: 5.4769
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 23 | train: 5.5246 | val: 5.4280
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 24 | train: 5.5613 | val: 5.3755
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 25 | train: 5.4774 | val: 5.3313
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 26 | train: 5.3540 | val: 5.2893
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 27 | train: 5.4009 | val: 5.2480
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 28 | train: 5.2688 | val: 5.2087
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 29 | train: 5.2778 | val: 5.1716
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 30 | train: 5.3138 | val: 5.1329
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 31 | train: 5.3784 | val: 5.0959
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 32 | train: 5.2792 | val: 5.0645
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 33 | train: 5.3743 | val: 5.0252
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 34 | train: 5.2439 | val: 4.9877
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 35 | train: 5.0045 | val: 4.9577
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 36 | train: 5.2160 | val: 4.8952
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 37 | train: 5.1952 | val: 4.8326
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 38 | train: 5.1019 | val: 4.7826
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 39 | train: 5.0336 | val: 4.7404
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 40 | train: 4.9648 | val: 4.6898
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 41 | train: 4.9893 | val: 4.6364
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 42 | train: 5.0229 | val: 4.5700
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 43 | train: 4.9185 | val: 4.4969
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 44 | train: 4.8801 | val: 4.4253
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 45 | train: 4.8002 | val: 4.3493
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 46 | train: 4.7542 | val: 4.2659
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 47 | train: 4.7089 | val: 4.1832
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 48 | train: 4.5209 | val: 4.1165
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 49 | train: 4.7166 | val: 4.0464
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 50 | train: 4.6801 | val: 3.9839
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 51 | train: 4.5771 | val: 3.9162
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 52 | train: 4.5512 | val: 3.8543
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 53 | train: 4.7637 | val: 3.8036
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 54 | train: 4.5797 | val: 3.7571
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 55 | train: 4.4047 | val: 3.7180
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 56 | train: 4.6061 | val: 3.6765
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 57 | train: 4.4013 | val: 3.6488
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 58 | train: 4.3387 | val: 3.6325
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 59 | train: 4.3739 | val: 3.6162
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 60 | train: 4.4739 | val: 3.6061
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 61 | train: 4.2567 | val: 3.5954
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 62 | train: 4.2096 | val: 3.5914
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 63 | train: 4.3582 | val: 3.5878
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 64 | train: 4.3917 | val: 3.5864
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 65 | train: 4.3122 | val: 3.5803
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 66 | train: 4.4758 | val: 3.5768
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 67 | train: 4.2105 | val: 3.5746
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 68 | train: 4.2600 | val: 3.5745
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 69 | train: 4.3007 | val: 3.5704
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 70 | train: 4.1957 | val: 3.5666
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 71 | train: 4.2975 | val: 3.5607
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 72 | train: 4.2190 | val: 3.5507
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 73 | train: 4.2254 | val: 3.5413
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 74 | train: 4.4081 | val: 3.5431
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 75 | train: 4.1976 | val: 3.5395
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 76 | train: 4.3896 | val: 3.5047
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 77 | train: 4.1499 | val: 3.4742
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 78 | train: 4.1996 | val: 3.4475
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 79 | train: 4.2525 | val: 3.4167
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 80 | train: 4.1776 | val: 3.3726
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 81 | train: 4.0717 | val: 3.3432
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 82 | train: 4.0395 | val: 3.3251
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 83 | train: 3.8747 | val: 3.3003
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 84 | train: 3.9548 | val: 3.2741
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 85 | train: 4.0062 | val: 3.2339
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 86 | train: 3.7673 | val: 3.2049
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 87 | train: 3.7935 | val: 3.1814
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 88 | train: 3.9725 | val: 3.1571
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 89 | train: 3.9844 | val: 3.1293
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 90 | train: 3.9386 | val: 3.1011
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 91 | train: 3.7884 | val: 3.0754
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 92 | train: 3.5462 | val: 3.0537
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 93 | train: 3.6007 | val: 3.0458
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 94 | train: 3.5798 | val: 3.0387
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 95 | train: 3.6330 | val: 3.0382
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 96 | train: 3.7662 | val: 3.0419
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 97 | train: 3.5681 | val: 3.0406
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 98 | train: 3.5969 | val: 3.0318
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 99 | train: 3.4592 | val: 3.0076
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 100 | train: 3.5283 | val: 2.9802
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 101 | train: 3.4033 | val: 2.9484
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 102 | train: 3.5601 | val: 2.9256
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 103 | train: 3.2679 | val: 2.9055
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 104 | train: 3.4318 | val: 2.8888
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 105 | train: 3.4382 | val: 2.8762
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 106 | train: 3.5061 | val: 2.8541
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 107 | train: 3.4407 | val: 2.8308
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 108 | train: 3.5493 | val: 2.8141
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 109 | train: 3.2080 | val: 2.8066
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 110 | train: 3.4179 | val: 2.8086
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 111 | train: 3.1792 | val: 2.8172
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 112 | train: 3.3852 | val: 2.8350
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 113 | train: 3.4013 | val: 2.8466
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 114 | train: 3.1927 | val: 2.8417
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 115 | train: 3.1768 | val: 2.8338
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 116 | train: 3.3281 | val: 2.8232
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 117 | train: 3.2743 | val: 2.8141
# Stopping early (signal model)
# Flow(
#   (_transform): CompositeTransform(
#     (_transforms): ModuleList(
#       (0): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (1): RandomPermutation()
#       (2): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (3): RandomPermutation()
#       (4): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (5): RandomPermutation()
#       (6): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (7): RandomPermutation()
#     )
#   )
#   (_distribution): StandardNormal()
#   (_embedding_net): Identity()
# )

# %%
# Signal training
def trainSignal():
    # modify notebook-level variables rather than creating locals
    global best_val_S, best_state_S, patience_S, sig_train_losses, sig_val_losses
    for epoch in range(1, EPOCHS_SIG + 1):
        train_loss = r_anode_mass_joint_untransformed(
            model_S=model_S,
            w=signal_fraction,
            optimizer=optimizer_S,
            data_loader=train_loader_S,
            device=device,
            mode="train",
            scheduler=scheduler_S,
        )
        val_loss = r_anode_mass_joint_untransformed(
            model_S=model_S,
            w=signal_fraction,
            optimizer=optimizer_S,
            data_loader=val_loader_S,
            device=device,
            mode="val",
        )
        sig_train_losses.append(float(train_loss))
        sig_val_losses.append(float(val_loss))
        print(f"[Signal] Epoch {epoch:02d} | train: {train_loss:.4f} | val: {val_loss:.4f}")
        if val_loss < best_val_S - 1e-4:
            best_val_S = val_loss
            best_state_S = copy.deepcopy({k: v.cpu() for k, v in model_S.state_dict().items()})
            patience_S = 0
        else:
            patience_S += 1
            if patience_S >= PATIENCE_LIMIT_S:
                print("Stopping early (signal model)")
                break
        scheduler_S.step()

    if best_state_S is not None:
        model_S.load_state_dict(best_state_S)
    model_S.to(device)
    model_S.eval()

trainSignal()
# Out:
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 01 | train: 1.0603 | val: 1.0070
# Stopping early (signal model)

# %%
# Plot training curves for background and signal models
fig, ax = plt.subplots(1, 2, figsize=(12, 4), sharex=True)
ax[0].plot(bkg_train_losses, label="Train")
ax[0].plot(bkg_val_losses, label="Validation")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].set_title("Background Flow Training")
ax[0].legend()

ax[1].plot(sig_train_losses, label="Train")
ax[1].plot(sig_val_losses, label="Validation")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Loss")
ax[1].set_title("Signal Flow Training")
ax[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpreting the density plot**
#
# The histogram shows the distribution of the likelihood ratio for signal (orange) and background (blue) events. Values greater than 1 mean the signal model assigns higher density than the background model for that event, but background events can still produce \(R>1\) because the two densities overlap in feature space. What matters is the relative separation of the two curves: the farther the orange curve sits to the right of the blue one, the easier it is to choose a threshold on \(R\) that keeps signal while rejecting background. The ROC curve below quantifies that separation across all thresholds.

# %%
# --- evaluate anomaly scores on held-out sample ---
with torch.no_grad():
    test_shifted_tensor = torch.from_numpy(SR_test_shifted.astype("float32")).to(device)
    sig_log_prob = model_S.log_prob(
        inputs=test_shifted_tensor[:, 1:-1],
        context=test_shifted_tensor[:, 0:1],
    ).cpu().numpy()

sig_prob = np.exp(sig_log_prob)
bg_prob = np.exp(log_B_test.flatten()) * mass_pdf_test
ratio = sig_prob / (bg_prob + 1e-12)

labels = SR_test[:, -1]

plt.figure(figsize=(7, 4))
plt.hist(ratio[labels == 0], bins=40, density=True, histtype='step', linewidth=2, color='tab:blue', label='Background')
plt.hist(ratio[labels == 1], bins=40, density=True, histtype='stepfilled', alpha=0.4, color='tab:orange', label='Signal')
plt.yscale("log")
plt.xlabel("R(x) = p_sig / p_bg")
plt.ylabel("Density")
plt.legend()
plt.title("Residual ANODE Anomaly Score")
plt.show()

signal_eff = (ratio[labels == 1] > 1.0).mean()
background_eff = (ratio[labels == 0] > 1.0).mean()
print(f"Signal efficiency at R>1: {signal_eff:.3f}")
print(f"Background efficiency at R>1: {background_eff:.3f}")

score_df = pd.DataFrame(
    {
        "time_ms": SR_test[:, 0],
        "label": labels,
        "sig_prob": sig_prob,
        "bg_prob": bg_prob,
        "anomaly_ratio": ratio,
    }
)
csv_path = project_root / "notebooks" / "anomaly_scores.csv"
score_df.to_csv(csv_path, index=False)
print(f"Saved anomaly scores to {csv_path}")
# Out:
# Signal efficiency at R>1: 1.000
# Background efficiency at R>1: 1.000
# Saved anomaly scores to /Users/krishwu/code/ranode/notebooks/anomaly_scores.csv

# %%
fpr, tpr, thresholds = roc_curve(labels, ratio)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], 'k--', alpha=0.6)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for R-Anode Score")
plt.legend(loc="lower right")
plt.grid(True, alpha=0.2)
plt.show()

# %%
# --- visualize strains vs time and distributions for data vs learned models ---
def sample_subset(data: np.ndarray, max_points: int = 600, rng: np.random.Generator = np.random.default_rng()):
    if len(data) <= max_points:
        return data
    idx = rng.choice(len(data), size=max_points, replace=False)
    return data[idx]

with torch.no_grad():
    cond_inputs = torch.from_numpy(SR_bkg_aligned_raw[:, 0].astype("float32")).reshape(-1, 1).to(device)
    bg_generated = model_B.model.sample(num_samples=cond_inputs.shape[0], cond_inputs=cond_inputs).cpu().numpy()
    sig_context = torch.from_numpy(SR_sig_shifted[:, 0:1].astype("float32")).to(device)
    generated = []
    for ctx in torch.split(sig_context, 1, dim=0):
        sample = model_S.sample(num_samples=1, context=ctx).cpu().numpy()
        if sample.ndim == 3:
            sample = sample[0, 0]
        elif sample.ndim == 2:
            sample = sample[0]
        generated.append(np.asarray(sample))
    sig_generated_features = np.stack(generated, axis=0)

bg_generated_full = np.concatenate([SR_bkg_aligned_raw[:, 0:1], bg_generated, np.zeros((bg_generated.shape[0], 1))], axis=1)
bg_generated_raw = inverse_transform(bg_generated_full, pre_params)

sig_time = sig_context.cpu().numpy() + center_time
sig_generated_features = np.atleast_2d(sig_generated_features)
sig_generated_processed = np.concatenate([sig_time, sig_generated_features, np.ones((sig_generated_features.shape[0], 1))], axis=1)
sig_generated_raw = inverse_transform(sig_generated_processed, pre_params)

plot_sets = {
    "Background Data": SR_bkg_aligned_raw,
    "Signal Data": SR_sig_aligned_raw,
    "Background Model": bg_generated_raw,
    "Signal Model": sig_generated_raw,
}

feature_names = [
    ("H_strain", 1),
    ("L_strain", 2),
    ("H+L", 3),
    ("H-L", 4),
 ]

rng = np.random.default_rng(2025)
for name, idx in feature_names:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    all_values = []
    for label, dataset in plot_sets.items():
        all_values.append(dataset[:, idx])
        subset = sample_subset(dataset, max_points=600, rng=rng)
        axes[0].scatter(subset[:, 0], subset[:, idx], label=label, s=10, alpha=0.5)
    axes[0].set_xlabel("Time [ms]")
    axes[0].set_ylabel(name)
    axes[0].set_title(f"{name} vs Time")
    axes[0].legend()

    values_concat = np.concatenate(all_values)
    vmin = np.quantile(values_concat, 0.01)
    vmax = np.quantile(values_concat, 0.99)
    bins = np.linspace(vmin, vmax, 60)

    for label, dataset in plot_sets.items():
        axes[1].hist(dataset[:, idx], bins=bins, histtype="step", density=True, label=label)

    axes[1].set_xlabel(name)
    axes[1].set_ylabel("Density")
    axes[1].set_title(f"{name} Distribution")
    axes[1].legend()
    plt.tight_layout()
    plt.show()
