# %% [markdown]
# # R-Anode Gravitational Wave Demo

# %% [markdown]
# Generate toy gravitational wave background and signal events
#
# Preprocess and split the data into sidebands (control) and signal regions
#
# Train the background density estimator (normalizing flow)
#
# Train the residual signal flow with a fixed signal fraction hypothesis
#
# Evaluate the learned anomaly score on a held-out sample
#
#
# All heavy Luigi/Law orchestration is skipped so the core R-Anode logic can be inspected interactively.

# %%
import os
import sys
import copy
import json
import pathlib
import numpy as np
import pandas as pd
import torch
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# ensure project root (with 'config/' and 'src/') is on sys.path
project_root = pathlib.Path.cwd().resolve()
if not (project_root / "config").exists():
    candidate = project_root.parent
    if (candidate / "config").exists():
        project_root = candidate
if (project_root / "config").exists() and str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print(f"Using project root: {project_root}")

from config import configs
from src.data_prep.gw_processing import process_gw_backgrounds, process_gw_signals, gw_background_split
from src.data_prep.utils import preprocess_params_fit, logit_transform, standardize, inverse_transform
from src.models.model_B import DensityEstimator, anode
from src.models.model_S import flows_model_RQS, r_anode_mass_joint_untransformed
from scipy.stats import rv_histogram

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
if device.type == "mps":
    torch.set_default_dtype(torch.float32)
torch.set_default_dtype(torch.float32)

torch.manual_seed(42)
# Out:
# Using project root: /Users/krishwu/code/ranode
# Using device: mps

# %%
SIGNAL_AMPLITUDE = 120.0  # tweak amplitude to study sensitivity

raw_bkg = process_gw_backgrounds()
raw_sig = process_gw_signals(amplitude=SIGNAL_AMPLITUDE)

def combine_signal_with_background(background: np.ndarray, signal: np.ndarray, scale: float = 1.0) -> np.ndarray:
    if background.shape != signal.shape:
        raise ValueError("Signal and background must share identical shape")
    combined = background.copy()
    if not np.allclose(background[:, 0], signal[:, 0], atol=1e-8):
        raise ValueError("Time grids for signal and background do not align")
    combined[:, 1] = background[:, 1] + scale * signal[:, 1]
    combined[:, 2] = background[:, 2] + scale * signal[:, 2]
    combined[:, 3] = combined[:, 1] + combined[:, 2]
    combined[:, 4] = combined[:, 1] - combined[:, 2]
    combined[:, -1] = 1.0
    return combined

combined_signal_raw = combine_signal_with_background(raw_bkg, raw_sig)
assert np.allclose(combined_signal_raw[:, 0], raw_bkg[:, 0])
assert np.allclose(combined_signal_raw[:, 1] - raw_bkg[:, 1], raw_sig[:, 1])
assert np.allclose(combined_signal_raw[:, 2] - raw_bkg[:, 2], raw_sig[:, 2])
assert np.allclose(combined_signal_raw[:, 3], combined_signal_raw[:, 1] + combined_signal_raw[:, 2])
assert np.allclose(combined_signal_raw[:, 4], combined_signal_raw[:, 1] - combined_signal_raw[:, 2])
print("Verified: signal is added sample-wise to the background")

print(f"Background shape: {raw_bkg.shape}")
print(f"Signal template shape: {raw_sig.shape}")
print(f"Signal+background combined shape: {combined_signal_raw.shape}")
print("Columns: [time, H, L, H+L, H-L, label]")
# Out:
# Verified: signal is added sample-wise to the background
# Background shape: (300, 6)
# Signal template shape: (300, 6)
# Signal+background combined shape: (300, 6)
# Columns: [time, H, L, H+L, H-L, label]

# %%
# --- split background into signal/control regions and fit preprocessing ---
SR_bkg_raw, CR_bkg_raw = gw_background_split(raw_bkg, resample_seed=42)
# I am instead basing the preprocessing params on the signal region. IMPORTANT NOTE for KRISH
# pre_params = preprocess_params_fit(CR_bkg_raw)
SR_sig_raw, CR_sig_raw = gw_background_split(combined_signal_raw, resample_seed=42)
pre_params = preprocess_params_fit(SR_sig_raw)
feature_min = pre_params["min"]
feature_max = pre_params["max"]
feature_range = feature_max - feature_min
buffer = np.maximum(feature_range * 0.1, 1e-3)
pre_params["min"] = feature_min - buffer
pre_params["max"] = feature_max + buffer
print("Pre_params:", pre_params)

def transform_with_params(data, params, clip_eps=1e-6):
    feature_min = params["min"]
    feature_max = params["max"]
    feature_mean = params["mean"]
    feature_std = params["std"]

    denom = feature_max - feature_min
    denom = np.where(denom == 0, 1e-6, denom)
    x = data[:, 1:-1]
    x_norm = (x - feature_min) / denom
    x_norm = np.clip(x_norm, clip_eps, 1 - clip_eps)
    logit = np.log(x_norm / (1 - x_norm))
    mask = np.isfinite(logit).all(axis=1)

    transformed = np.hstack([data[:, 0:1], logit, data[:, -1:]])[mask]
    transformed[:, 1:-1] = standardize(transformed[:, 1:-1], feature_mean, feature_std)
    return transformed, data[mask]

CR_processed, CR_aligned_raw = transform_with_params(CR_bkg_raw, pre_params)
SR_bkg_processed, SR_bkg_aligned_raw = transform_with_params(SR_bkg_raw, pre_params)
SR_sig_processed, SR_sig_aligned_raw = transform_with_params(SR_sig_raw, pre_params)

print(f"Control-region processed shape: {CR_processed.shape}")
print(f"Signal-region background shape: {SR_bkg_processed.shape}")
print(f"Signal-region injected signal shape: {SR_sig_processed.shape}")

# Build background mass/time PDF for later mixing
hist_counts, hist_bins = np.histogram(SR_bkg_aligned_raw[:, 0], bins=40, density=True)
mass_density = rv_histogram((hist_counts, hist_bins))

plt.clf()
# plt.scatter(SR_bkg_raw[:, 0], SR_bkg_raw[:, 1], label='Signal Region Background Time Distribution')
# plt.scatter(CR_bkg_raw[:, 0], CR_bkg_raw[:, 1], label='Control Region Background Time Distribution')
plt.scatter(SR_bkg_processed[:, 0], SR_bkg_processed[:, 1], label='Processed Signal Region Background Time Distribution')
plt.scatter(SR_sig_processed[:, 0], SR_sig_processed[:, 1], label='Processed Signal+Background Time Distribution')
# plt.scatter(CR_sig_raw[:, 0], CR_sig_raw[:, 1], label='Signal Region Raw Signal+Background Time Distribution')
plt.scatter(CR_processed[:, 0], CR_processed[:, 1], label='Processed Control Region Background Time Distribution')
plt.xlabel('Time (s)')
plt.ylabel('Strain')
plt.legend()
plt.title('Gravitational Wave Data Processing')
plt.show()
# Out:
# GW Background split: Inner=150, Outer=150
# GW Background split: Inner=150, Outer=150
# Pre_params: {'min': array([-2.7248861 , -3.06011921, -4.2396346 , -4.36058515]), 'max': array([2.7767214 , 2.84876591, 4.23655865, 4.58709463]), 'mean': array([ 0.03327492,  0.12399584,  0.04568714, -0.06563688]), 'std': array([0.94668147, 0.80407836, 0.8269974 , 0.71777053])}
# Control-region processed shape: (150, 6)
# Signal-region background shape: (150, 6)
# Signal-region injected signal shape: (150, 6)

# %%
plt.clf()
plt.hist(SR_bkg_processed[:, 1], bins=40, alpha=0.5, label='Signal Region Background Time Histogram')
plt.hist(CR_processed[:, 1], bins=40, alpha=0.5, label='Control Region Background Time Histogram')
plt.hist(SR_sig_processed[:, 1], bins=40, alpha=0.5, label='Signal+Background Time Histogram')
plt.xlabel('Strain')
plt.ylabel('Density')
plt.legend()
plt.title('Strain Distribution Comparison')
plt.show()

# %%
# --- train the background normalizing flow on CR data ---
CR_train, CR_val = train_test_split(CR_processed, test_size=0.25, random_state=42, shuffle=True)

train_tensor = torch.from_numpy(CR_train.astype("float32")).to(device)
val_tensor = torch.from_numpy(CR_val.astype("float32")).to(device)

train_loader = DataLoader(TensorDataset(train_tensor), batch_size=512, shuffle=True)
val_loader = DataLoader(TensorDataset(val_tensor), batch_size=1024, shuffle=False)

config_path = project_root / "src" / "models" / "DE_MAF_model.yml"
model_B = DensityEstimator(str(config_path), eval_mode=False, device=device)

bkg_train_losses = []
bkg_val_losses = []
best_state = None
best_val = float("inf")
patience = 0
PATIENCE_LIMIT = 5
EPOCHS_BKG = 200

for epoch in range(1, EPOCHS_BKG + 1):
    train_loss = anode(model_B.model, train_loader, model_B.optimizer, params=None, device=device, mode="train")
    val_loss = anode(model_B.model, val_loader, model_B.optimizer, params=None, device=device, mode="val")
    bkg_train_losses.append(float(train_loss))
    bkg_val_losses.append(float(val_loss))
    print(f"[Bkg] Epoch {epoch:02d} | train: {train_loss:.4f} | val: {val_loss:.4f}")
    if val_loss < best_val - 1e-4:
        best_val = val_loss
        best_state = copy.deepcopy({k: v.cpu() for k, v in model_B.model.state_dict().items()})
        patience = 0
    else:
        patience += 1
        if patience >= PATIENCE_LIMIT:
            print("Stopping early (background model)")
            break

if best_state is not None:
    model_B.model.load_state_dict(best_state)
model_B.model.to(device)
model_B.model.eval()
# Out:
# DensityEstimator has 274800 parameters
# setting batch norm layers to eval mode
# [Bkg] Epoch 01 | train: 124.2158 | val: 118.9740
# setting batch norm layers to eval mode
# [Bkg] Epoch 02 | train: 116.9772 | val: 110.1623
# setting batch norm layers to eval mode
# [Bkg] Epoch 03 | train: 108.2723 | val: 104.7436
# setting batch norm layers to eval mode
# [Bkg] Epoch 04 | train: 102.9737 | val: 96.8216
# setting batch norm layers to eval mode
# [Bkg] Epoch 05 | train: 95.1032 | val: 91.8834
# setting batch norm layers to eval mode
# [Bkg] Epoch 06 | train: 90.2818 | val: 86.2809
# setting batch norm layers to eval mode
# [Bkg] Epoch 07 | train: 84.7934 | val: 80.0748
# setting batch norm layers to eval mode
# [Bkg] Epoch 08 | train: 78.5721 | val: 75.9982
# setting batch norm layers to eval mode
# [Bkg] Epoch 09 | train: 74.4455 | val: 71.5493
# setting batch norm layers to eval mode
# [Bkg] Epoch 10 | train: 70.0416 | val: 67.4478
# setting batch norm layers to eval mode
# [Bkg] Epoch 11 | train: 66.0968 | val: 63.9895
# setting batch norm layers to eval mode
# [Bkg] Epoch 12 | train: 62.7088 | val: 62.4523
# setting batch norm layers to eval mode
# [Bkg] Epoch 13 | train: 61.2964 | val: 59.5279
# setting batch norm layers to eval mode
# [Bkg] Epoch 14 | train: 58.2842 | val: 56.5485
# setting batch norm layers to eval mode
# [Bkg] Epoch 15 | train: 55.2804 | val: 54.4054
# setting batch norm layers to eval mode
# [Bkg] Epoch 16 | train: 53.1611 | val: 51.4606
# setting batch norm layers to eval mode
# [Bkg] Epoch 17 | train: 50.1920 | val: 50.4681
# setting batch norm layers to eval mode
# [Bkg] Epoch 18 | train: 49.2194 | val: 46.5550
# setting batch norm layers to eval mode
# [Bkg] Epoch 19 | train: 45.3188 | val: 46.5402
# setting batch norm layers to eval mode
# [Bkg] Epoch 20 | train: 45.3716 | val: 41.8322
# setting batch norm layers to eval mode
# [Bkg] Epoch 21 | train: 40.8040 | val: 42.2115
# setting batch norm layers to eval mode
# [Bkg] Epoch 22 | train: 41.6069 | val: 39.7160
# setting batch norm layers to eval mode
# [Bkg] Epoch 23 | train: 39.4078 | val: 36.4443
# setting batch norm layers to eval mode
# [Bkg] Epoch 24 | train: 36.3126 | val: 35.5374
# setting batch norm layers to eval mode
# [Bkg] Epoch 25 | train: 35.1499 | val: 31.6608
# setting batch norm layers to eval mode
# [Bkg] Epoch 26 | train: 31.2160 | val: 32.6945
# setting batch norm layers to eval mode
# [Bkg] Epoch 27 | train: 32.3163 | val: 31.6107
# setting batch norm layers to eval mode
# [Bkg] Epoch 28 | train: 31.3139 | val: 28.8125
# setting batch norm layers to eval mode
# [Bkg] Epoch 29 | train: 28.9899 | val: 28.8959
# setting batch norm layers to eval mode
# [Bkg] Epoch 30 | train: 29.1757 | val: 26.6189
# setting batch norm layers to eval mode
# [Bkg] Epoch 31 | train: 26.9538 | val: 25.0676
# setting batch norm layers to eval mode
# [Bkg] Epoch 32 | train: 25.2718 | val: 23.8253
# setting batch norm layers to eval mode
# [Bkg] Epoch 33 | train: 23.9352 | val: 22.9577
# setting batch norm layers to eval mode
# [Bkg] Epoch 34 | train: 22.2315 | val: 21.4304
# setting batch norm layers to eval mode
# [Bkg] Epoch 35 | train: 21.1901 | val: 19.1043
# setting batch norm layers to eval mode
# [Bkg] Epoch 36 | train: 19.1456 | val: 18.2202
# setting batch norm layers to eval mode
# [Bkg] Epoch 37 | train: 18.6866 | val: 15.8703
# setting batch norm layers to eval mode
# [Bkg] Epoch 38 | train: 16.3194 | val: 17.5502
# setting batch norm layers to eval mode
# [Bkg] Epoch 39 | train: 17.6665 | val: 16.8657
# setting batch norm layers to eval mode
# [Bkg] Epoch 40 | train: 16.9192 | val: 15.1993
# setting batch norm layers to eval mode
# [Bkg] Epoch 41 | train: 15.3437 | val: 15.7327
# setting batch norm layers to eval mode
# [Bkg] Epoch 42 | train: 15.7104 | val: 14.5372
# setting batch norm layers to eval mode
# [Bkg] Epoch 43 | train: 14.5596 | val: 12.6903
# setting batch norm layers to eval mode
# [Bkg] Epoch 44 | train: 12.5011 | val: 10.2345
# setting batch norm layers to eval mode
# [Bkg] Epoch 45 | train: 10.5073 | val: 11.6901
# setting batch norm layers to eval mode
# [Bkg] Epoch 46 | train: 11.8533 | val: 11.2904
# setting batch norm layers to eval mode
# [Bkg] Epoch 47 | train: 11.4169 | val: 11.0484
# setting batch norm layers to eval mode
# [Bkg] Epoch 48 | train: 11.4645 | val: 9.9315
# setting batch norm layers to eval mode
# [Bkg] Epoch 49 | train: 10.5016 | val: 9.5673
# setting batch norm layers to eval mode
# [Bkg] Epoch 50 | train: 10.1943 | val: 8.2008
# setting batch norm layers to eval mode
# [Bkg] Epoch 51 | train: 8.8456 | val: 7.4313
# setting batch norm layers to eval mode
# [Bkg] Epoch 52 | train: 7.9031 | val: 7.4093
# setting batch norm layers to eval mode
# [Bkg] Epoch 53 | train: 7.6901 | val: 7.0631
# setting batch norm layers to eval mode
# [Bkg] Epoch 54 | train: 7.3600 | val: 6.2025
# setting batch norm layers to eval mode
# [Bkg] Epoch 55 | train: 6.6851 | val: 5.9907
# setting batch norm layers to eval mode
# [Bkg] Epoch 56 | train: 6.5212 | val: 5.6354
# setting batch norm layers to eval mode
# [Bkg] Epoch 57 | train: 6.0566 | val: 5.6085
# setting batch norm layers to eval mode
# [Bkg] Epoch 58 | train: 5.8053 | val: 5.0449
# setting batch norm layers to eval mode
# [Bkg] Epoch 59 | train: 5.1851 | val: 4.8359
# setting batch norm layers to eval mode
# [Bkg] Epoch 60 | train: 4.7727 | val: 4.7098
# setting batch norm layers to eval mode
# [Bkg] Epoch 61 | train: 4.4488 | val: 4.2658
# setting batch norm layers to eval mode
# [Bkg] Epoch 62 | train: 4.0329 | val: 3.7364
# setting batch norm layers to eval mode
# [Bkg] Epoch 63 | train: 3.6855 | val: 3.5355
# setting batch norm layers to eval mode
# [Bkg] Epoch 64 | train: 3.3450 | val: 3.3318
# setting batch norm layers to eval mode
# [Bkg] Epoch 65 | train: 3.2081 | val: 3.0750
# setting batch norm layers to eval mode
# [Bkg] Epoch 66 | train: 2.8760 | val: 3.0499
# setting batch norm layers to eval mode
# [Bkg] Epoch 67 | train: 3.0082 | val: 2.8471
# setting batch norm layers to eval mode
# [Bkg] Epoch 68 | train: 2.8640 | val: 2.8944
# setting batch norm layers to eval mode
# [Bkg] Epoch 69 | train: 2.4305 | val: 2.9267
# setting batch norm layers to eval mode
# [Bkg] Epoch 70 | train: 2.4607 | val: 2.7254
# setting batch norm layers to eval mode
# [Bkg] Epoch 71 | train: 2.0512 | val: 2.8687
# setting batch norm layers to eval mode
# [Bkg] Epoch 72 | train: 2.5673 | val: 1.9661
# setting batch norm layers to eval mode
# [Bkg] Epoch 73 | train: 1.7054 | val: 1.6169
# setting batch norm layers to eval mode
# [Bkg] Epoch 74 | train: 1.4422 | val: 0.9199
# setting batch norm layers to eval mode
# [Bkg] Epoch 75 | train: 0.9657 | val: 0.4407
# setting batch norm layers to eval mode
# [Bkg] Epoch 76 | train: 0.4747 | val: 0.0407
# setting batch norm layers to eval mode
# [Bkg] Epoch 77 | train: 0.1334 | val: 0.5169
# setting batch norm layers to eval mode
# [Bkg] Epoch 78 | train: 0.3642 | val: 0.4768
# setting batch norm layers to eval mode
# [Bkg] Epoch 79 | train: 0.3313 | val: 0.1998
# setting batch norm layers to eval mode
# [Bkg] Epoch 80 | train: 0.0597 | val: -0.0619
# setting batch norm layers to eval mode
# [Bkg] Epoch 81 | train: -0.1772 | val: -0.5070
# setting batch norm layers to eval mode
# [Bkg] Epoch 82 | train: -0.4917 | val: -0.3280
# setting batch norm layers to eval mode
# [Bkg] Epoch 83 | train: -0.2360 | val: -0.5169
# setting batch norm layers to eval mode
# [Bkg] Epoch 84 | train: -0.4410 | val: -0.5470
# setting batch norm layers to eval mode
# [Bkg] Epoch 85 | train: -0.7500 | val: -0.3945
# setting batch norm layers to eval mode
# [Bkg] Epoch 86 | train: -0.8151 | val: -0.3168
# setting batch norm layers to eval mode
# [Bkg] Epoch 87 | train: -0.5715 | val: -0.3559
# setting batch norm layers to eval mode
# [Bkg] Epoch 88 | train: -0.5463 | val: -0.9388
# setting batch norm layers to eval mode
# [Bkg] Epoch 89 | train: -0.7486 | val: -0.6101
# setting batch norm layers to eval mode
# [Bkg] Epoch 90 | train: -0.4890 | val: -0.7437
# setting batch norm layers to eval mode
# [Bkg] Epoch 91 | train: -0.6045 | val: -1.0745
# setting batch norm layers to eval mode
# [Bkg] Epoch 92 | train: -0.9787 | val: -1.2457
# setting batch norm layers to eval mode
# [Bkg] Epoch 93 | train: -1.1931 | val: -0.9860
# setting batch norm layers to eval mode
# [Bkg] Epoch 94 | train: -1.2076 | val: -0.2084
# setting batch norm layers to eval mode
# [Bkg] Epoch 95 | train: -0.7699 | val: -0.4675
# setting batch norm layers to eval mode
# [Bkg] Epoch 96 | train: -1.0927 | val: -1.2601
# setting batch norm layers to eval mode
# [Bkg] Epoch 97 | train: -1.4802 | val: -1.3821
# setting batch norm layers to eval mode
# [Bkg] Epoch 98 | train: -1.5091 | val: -1.8228
# setting batch norm layers to eval mode
# [Bkg] Epoch 99 | train: -2.2109 | val: -0.9303
# setting batch norm layers to eval mode
# [Bkg] Epoch 100 | train: -1.3418 | val: -1.6520
# setting batch norm layers to eval mode
# [Bkg] Epoch 101 | train: -1.6511 | val: -1.8636
# setting batch norm layers to eval mode
# [Bkg] Epoch 102 | train: -1.9227 | val: -1.2247
# setting batch norm layers to eval mode
# [Bkg] Epoch 103 | train: -1.5729 | val: -2.3647
# setting batch norm layers to eval mode
# [Bkg] Epoch 104 | train: -2.6079 | val: -1.9133
# setting batch norm layers to eval mode
# [Bkg] Epoch 105 | train: -1.9443 | val: -1.1809
# setting batch norm layers to eval mode
# [Bkg] Epoch 106 | train: -1.6740 | val: -2.1017
# setting batch norm layers to eval mode
# [Bkg] Epoch 107 | train: -2.4589 | val: -1.5740
# setting batch norm layers to eval mode
# [Bkg] Epoch 108 | train: -2.0716 | val: -1.9721
# Stopping early (background model)
# FlowSequential(
#   (0): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (1): BatchNormFlow()
#   (2): Reverse()
#   (3): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (4): BatchNormFlow()
#   (5): Reverse()
#   (6): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (7): BatchNormFlow()
#   (8): Reverse()
#   (9): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (10): BatchNormFlow()
#   (11): Reverse()
#   (12): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (13): BatchNormFlow()
#   (14): Reverse()
#   (15): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (16): BatchNormFlow()
#   (17): Reverse()
#   (18): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (19): BatchNormFlow()
#   (20): Reverse()
#   (21): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (22): BatchNormFlow()
#   (23): Reverse()
#   (24): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (25): BatchNormFlow()
#   (26): Reverse()
#   (27): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (28): BatchNormFlow()
#   (29): Reverse()
#   (30): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (31): BatchNormFlow()
#   (32): Reverse()
#   (33): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (34): BatchNormFlow()
#   (35): Reverse()
#   (36): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (37): BatchNormFlow()
#   (38): Reverse()
#   (39): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (40): BatchNormFlow()
#   (41): Reverse()
#   (42): MADE(
#     (joiner): MaskedLinear(
#       (linear): Linear(in_features=4, out_features=128, bias=True)
#       (cond_linear): Linear(in_features=1, out_features=128, bias=False)
#     )
#     (trunk): Sequential(
#       (0): ReLU()
#       (1): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (2): ReLU()
#       (3): MaskedLinear(
#         (linear): Linear(in_features=128, out_features=8, bias=True)
#       )
#     )
#   )
#   (43): BatchNormFlow()
#   (44): Reverse()
# )

# %%
# --- prepare signal-region datasets & background log probabilities ---
SR_combined_processed = np.vstack([SR_bkg_processed, SR_sig_processed])
SR_combined_raw = np.vstack([SR_bkg_aligned_raw, SR_sig_aligned_raw])

indices = np.arange(len(SR_combined_processed))
train_idx, test_idx = train_test_split(
    indices,
    test_size=0.2,
    random_state=1337,
    stratify=SR_combined_processed[:, -1],
)

SR_train_all = SR_combined_processed[train_idx]
SR_train_raw_all = SR_combined_raw[train_idx]
SR_test = SR_combined_processed[test_idx]
SR_test_raw = SR_combined_raw[test_idx]

with torch.no_grad():
    train_tensor_all = torch.from_numpy(SR_train_all.astype("float32")).to(device)
    log_B_train_all = model_B.model.log_probs(
        inputs=train_tensor_all[:, 1:-1],
        cond_inputs=train_tensor_all[:, 0:1],
    ).cpu().numpy()

    test_tensor = torch.from_numpy(SR_test.astype("float32")).to(device)
    log_B_test = model_B.model.log_probs(
        inputs=test_tensor[:, 1:-1],
        cond_inputs=test_tensor[:, 0:1],
    ).cpu().numpy()

mass_pdf_train_all = mass_density.pdf(SR_train_raw_all[:, 0])
mass_pdf_test = mass_density.pdf(SR_test_raw[:, 0])

# split train into (train, val)
inner_indices = np.arange(len(SR_train_all))
train_inner_idx, val_inner_idx = train_test_split(
    inner_indices,
    test_size=0.2,
    random_state=2024,
    stratify=SR_train_all[:, -1],
)

SR_train = SR_train_all[train_inner_idx]
SR_val = SR_train_all[val_inner_idx]
SR_train_raw = SR_train_raw_all[train_inner_idx]
SR_val_raw = SR_train_raw_all[val_inner_idx]

log_B_train = log_B_train_all[train_inner_idx]
log_B_val = log_B_train_all[val_inner_idx]

mass_pdf_train = mass_pdf_train_all[train_inner_idx]
mass_pdf_val = mass_pdf_train_all[val_inner_idx]

center_time = 0.5 * (configs.SR_MIN + configs.SR_MAX)
def shift_time(data):
    shifted = data.copy()
    shifted[:, 0] -= center_time
    return shifted

SR_train_shifted = shift_time(SR_train)
SR_val_shifted = shift_time(SR_val)
SR_test_shifted = shift_time(SR_test)
SR_sig_shifted = shift_time(SR_sig_processed)

signal_fraction = float(SR_train[:, -1].mean())
print(f"Training signal fraction w ≈ {signal_fraction:.4f}")
# Out:
# Training signal fraction w ≈ 0.5000

# %%
# --- train the residual signal flow ---
train_dataset = TensorDataset(
    torch.from_numpy(SR_train_shifted.astype("float32")).to(device),
    torch.from_numpy(log_B_train.astype("float32")).to(device),
    torch.from_numpy(mass_pdf_train.astype("float32")).to(device),
)
val_dataset = TensorDataset(
    torch.from_numpy(SR_val_shifted.astype("float32")).to(device),
    torch.from_numpy(log_B_val.astype("float32")).to(device),
    torch.from_numpy(mass_pdf_val.astype("float32")).to(device),
)

train_loader_S = DataLoader(train_dataset, batch_size=256, shuffle=True)
val_loader_S = DataLoader(val_dataset, batch_size=512, shuffle=False)

model_S = flows_model_RQS(
    num_layers=4,
    num_features=4,
    num_blocks=2,
    hidden_features=64,
    device=device,
    context_features=1,
)

optimizer_S = torch.optim.AdamW(model_S.parameters(), lr=3e-4)
scheduler_S = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer_S, T_0=10, T_mult=2)

sig_train_losses = []
sig_val_losses = []
best_state_S = None
best_val_S = float("inf")
patience_S = 0
PATIENCE_LIMIT_S = 8
EPOCHS_SIG = 200

for epoch in range(1, EPOCHS_SIG + 1):
    train_loss = r_anode_mass_joint_untransformed(
        model_S=model_S,
        w=signal_fraction,
        optimizer=optimizer_S,
        data_loader=train_loader_S,
        device=device,
        mode="train",
        scheduler=scheduler_S,
    )
    val_loss = r_anode_mass_joint_untransformed(
        model_S=model_S,
        w=signal_fraction,
        optimizer=optimizer_S,
        data_loader=val_loader_S,
        device=device,
        mode="val",
    )
    sig_train_losses.append(float(train_loss))
    sig_val_losses.append(float(val_loss))
    print(f"[Signal] Epoch {epoch:02d} | train: {train_loss:.4f} | val: {val_loss:.4f}")
    if val_loss < best_val_S - 1e-4:
        best_val_S = val_loss
        best_state_S = copy.deepcopy({k: v.cpu() for k, v in model_S.state_dict().items()})
        patience_S = 0
    else:
        patience_S += 1
        if patience_S >= PATIENCE_LIMIT_S:
            print("Stopping early (signal model)")
            break
    scheduler_S.step()

if best_state_S is not None:
    model_S.load_state_dict(best_state_S)
model_S.to(device)
model_S.eval()
# Out:
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 01 | train: 5.1291 | val: 5.7166
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 02 | train: 4.9634 | val: 5.3854
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 03 | train: 4.8338 | val: 5.1971
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 04 | train: 4.7481 | val: 5.0814
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 05 | train: 4.7966 | val: 5.0142
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 06 | train: 4.7852 | val: 4.9515
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 07 | train: 4.5536 | val: 4.9085
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 08 | train: 4.6612 | val: 4.8744
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 09 | train: 4.6947 | val: 4.8479
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 10 | train: 4.5364 | val: 4.8293
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 11 | train: 4.5469 | val: 4.8159
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 12 | train: 4.5956 | val: 4.8053
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 13 | train: 4.4986 | val: 4.7974
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 14 | train: 4.5365 | val: 4.7894
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 15 | train: 4.5593 | val: 4.7798
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 16 | train: 4.4546 | val: 4.7576
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 17 | train: 4.4643 | val: 4.7369
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 18 | train: 4.4826 | val: 4.7193
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 19 | train: 4.4980 | val: 4.7049
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 20 | train: 4.5653 | val: 4.6906
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 21 | train: 4.4138 | val: 4.6786
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 22 | train: 4.3405 | val: 4.6680
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 23 | train: 4.5479 | val: 4.6579
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 24 | train: 4.2879 | val: 4.6483
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 25 | train: 4.3079 | val: 4.6376
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 26 | train: 4.3227 | val: 4.6250
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 27 | train: 4.3717 | val: 4.6132
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 28 | train: 4.3177 | val: 4.6001
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 29 | train: 4.3531 | val: 4.5889
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 30 | train: 4.2205 | val: 4.5745
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 31 | train: 4.4265 | val: 4.5628
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 32 | train: 4.3245 | val: 4.5481
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 33 | train: 4.2687 | val: 4.5335
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 34 | train: 4.3035 | val: 4.5222
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 35 | train: 4.2723 | val: 4.5098
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 36 | train: 4.2637 | val: 4.4772
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 37 | train: 4.2030 | val: 4.4443
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 38 | train: 4.2780 | val: 4.4185
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 39 | train: 4.2616 | val: 4.3998
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 40 | train: 4.0921 | val: 4.3846
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 41 | train: 4.1832 | val: 4.3710
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 42 | train: 4.0659 | val: 4.3525
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 43 | train: 4.0332 | val: 4.3258
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 44 | train: 4.2374 | val: 4.3008
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 45 | train: 4.0948 | val: 4.2802
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 46 | train: 4.0695 | val: 4.2564
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 47 | train: 4.1445 | val: 4.2380
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 48 | train: 4.0845 | val: 4.2172
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 49 | train: 4.0099 | val: 4.1953
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 50 | train: 3.9636 | val: 4.1736
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 51 | train: 4.0154 | val: 4.1518
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 52 | train: 4.1413 | val: 4.1346
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 53 | train: 4.1109 | val: 4.1159
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 54 | train: 3.9786 | val: 4.0967
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 55 | train: 3.9980 | val: 4.0794
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 56 | train: 4.0747 | val: 4.0615
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 57 | train: 4.0046 | val: 4.0471
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 58 | train: 4.0311 | val: 4.0325
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 59 | train: 3.9897 | val: 4.0220
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 60 | train: 3.9394 | val: 4.0127
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 61 | train: 3.9979 | val: 4.0030
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 62 | train: 3.9354 | val: 3.9952
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 63 | train: 3.9515 | val: 3.9903
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 64 | train: 3.9614 | val: 3.9857
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 65 | train: 3.9932 | val: 3.9820
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 66 | train: 4.0459 | val: 3.9776
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 67 | train: 3.9409 | val: 3.9722
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 68 | train: 3.8914 | val: 3.9686
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 69 | train: 3.9126 | val: 3.9672
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 70 | train: 4.0571 | val: 3.9654
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 71 | train: 3.7981 | val: 3.9649
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 72 | train: 3.8731 | val: 3.9629
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 73 | train: 3.9239 | val: 3.9608
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 74 | train: 3.9532 | val: 3.9643
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 75 | train: 3.8254 | val: 3.9669
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 76 | train: 4.0388 | val: 3.9522
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 77 | train: 3.8809 | val: 3.9301
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 78 | train: 3.9110 | val: 3.9120
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 79 | train: 3.7799 | val: 3.8951
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 80 | train: 3.8452 | val: 3.8755
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 81 | train: 3.7402 | val: 3.8547
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 82 | train: 3.8469 | val: 3.8372
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 83 | train: 3.8687 | val: 3.8154
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 84 | train: 3.8470 | val: 3.7859
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 85 | train: 3.8620 | val: 3.7557
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 86 | train: 3.8361 | val: 3.7203
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 87 | train: 3.8505 | val: 3.6869
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 88 | train: 3.8151 | val: 3.6543
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 89 | train: 3.8099 | val: 3.6316
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 90 | train: 3.7168 | val: 3.6109
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 91 | train: 3.7046 | val: 3.5904
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 92 | train: 3.6556 | val: 3.5765
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 93 | train: 3.7174 | val: 3.5669
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 94 | train: 3.7267 | val: 3.5558
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 95 | train: 3.6424 | val: 3.5451
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 96 | train: 3.6094 | val: 3.5386
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 97 | train: 3.6821 | val: 3.5293
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 98 | train: 3.5309 | val: 3.5212
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 99 | train: 3.6350 | val: 3.5066
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 100 | train: 3.5200 | val: 3.4914
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 101 | train: 3.5001 | val: 3.4886
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 102 | train: 3.5267 | val: 3.4849
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 103 | train: 3.6055 | val: 3.4812
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 104 | train: 3.4459 | val: 3.4741
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 105 | train: 3.5110 | val: 3.4665
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 106 | train: 3.4884 | val: 3.4526
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 107 | train: 3.5490 | val: 3.4355
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 108 | train: 3.6719 | val: 3.4150
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 109 | train: 3.5661 | val: 3.3908
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 110 | train: 3.3282 | val: 3.3665
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 111 | train: 3.4746 | val: 3.3382
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 112 | train: 3.5146 | val: 3.3173
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 113 | train: 3.4831 | val: 3.2965
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 114 | train: 3.5128 | val: 3.2810
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 115 | train: 3.3908 | val: 3.2705
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 116 | train: 3.3595 | val: 3.2648
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 117 | train: 3.3429 | val: 3.2632
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 118 | train: 3.3832 | val: 3.2643
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 119 | train: 3.3623 | val: 3.2608
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 120 | train: 3.2507 | val: 3.2589
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 121 | train: 3.3606 | val: 3.2569
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 122 | train: 3.2540 | val: 3.2485
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 123 | train: 3.2668 | val: 3.2460
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 124 | train: 3.3314 | val: 3.2448
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 125 | train: 3.4370 | val: 3.2411
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 126 | train: 3.2754 | val: 3.2375
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 127 | train: 3.3413 | val: 3.2311
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 128 | train: 3.3356 | val: 3.2248
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 129 | train: 3.3126 | val: 3.2200
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 130 | train: 3.1959 | val: 3.2109
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 131 | train: 3.3169 | val: 3.2062
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 132 | train: 3.2030 | val: 3.2041
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 133 | train: 3.3570 | val: 3.2019
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 134 | train: 3.2362 | val: 3.1975
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 135 | train: 3.3853 | val: 3.1891
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 136 | train: 3.1630 | val: 3.1810
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 137 | train: 3.2874 | val: 3.1777
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 138 | train: 3.3612 | val: 3.1746
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 139 | train: 3.3912 | val: 3.1676
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 140 | train: 3.2590 | val: 3.1677
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 141 | train: 3.2858 | val: 3.1633
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 142 | train: 3.3085 | val: 3.1582
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 143 | train: 3.3861 | val: 3.1579
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 144 | train: 3.2926 | val: 3.1567
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 145 | train: 3.4012 | val: 3.1521
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 146 | train: 3.2311 | val: 3.1495
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 147 | train: 3.3123 | val: 3.1495
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 148 | train: 3.1747 | val: 3.1497
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 149 | train: 3.2674 | val: 3.1496
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 150 | train: 3.2232 | val: 3.1417
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 151 | train: 3.3839 | val: 3.1387
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 152 | train: 3.1498 | val: 3.1406
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 153 | train: 3.2558 | val: 3.1417
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 154 | train: 3.2675 | val: 3.1472
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 155 | train: 3.1960 | val: 3.1468
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 156 | train: 3.1547 | val: 3.1267
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 157 | train: 3.1597 | val: 3.1001
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 158 | train: 3.3469 | val: 3.0761
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 159 | train: 3.3150 | val: 3.0574
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 160 | train: 3.3167 | val: 3.0488
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 161 | train: 3.2253 | val: 3.0409
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 162 | train: 3.2528 | val: 3.0303
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 163 | train: 3.1720 | val: 3.0135
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 164 | train: 3.2243 | val: 2.9854
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 165 | train: 3.1060 | val: 2.9563
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 166 | train: 3.1391 | val: 2.9217
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 167 | train: 3.1780 | val: 2.9138
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 168 | train: 3.0677 | val: 2.9054
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 169 | train: 3.0366 | val: 2.9006
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 170 | train: 3.0783 | val: 2.9089
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 171 | train: 2.9138 | val: 2.9086
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 172 | train: 3.0948 | val: 2.8869
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 173 | train: 3.1991 | val: 2.8691
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 174 | train: 3.0174 | val: 2.8528
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 175 | train: 3.1418 | val: 2.8273
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 176 | train: 3.0534 | val: 2.7951
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 177 | train: 3.1015 | val: 2.7652
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 178 | train: 3.0494 | val: 2.7416
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 179 | train: 3.0517 | val: 2.7334
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 180 | train: 3.0087 | val: 2.7209
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 181 | train: 2.9674 | val: 2.7150
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 182 | train: 2.8044 | val: 2.7062
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 183 | train: 2.9070 | val: 2.6918
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 184 | train: 2.9305 | val: 2.6821
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 185 | train: 2.8204 | val: 2.6746
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 186 | train: 2.8601 | val: 2.6735
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 187 | train: 2.9188 | val: 2.6841
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 188 | train: 2.8418 | val: 2.7018
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 189 | train: 2.8680 | val: 2.7093
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 190 | train: 2.8167 | val: 2.7067
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 191 | train: 2.8556 | val: 2.7026
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 192 | train: 2.7619 | val: 2.6976
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 193 | train: 2.7142 | val: 2.6917
# value of w: 0.5
# value of w: 0.5
# [Signal] Epoch 194 | train: 2.7440 | val: 2.6899
# Stopping early (signal model)
# Flow(
#   (_transform): CompositeTransform(
#     (_transforms): ModuleList(
#       (0): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (1): RandomPermutation()
#       (2): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (3): RandomPermutation()
#       (4): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (5): RandomPermutation()
#       (6): MaskedPiecewiseRationalQuadraticAutoregressiveTransform(
#         (autoregressive_net): MADE(
#           (initial_layer): MaskedLinear(in_features=4, out_features=64, bias=True)
#           (context_layer): Linear(in_features=1, out_features=64, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x MaskedFeedforwardBlock(
#               (batch_norm): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (linear): MaskedLinear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.2, inplace=False)
#             )
#           )
#           (final_layer): MaskedLinear(in_features=64, out_features=92, bias=True)
#         )
#       )
#       (7): RandomPermutation()
#     )
#   )
#   (_distribution): StandardNormal()
#   (_embedding_net): Identity()
# )

# %%
# Plot training curves for background and signal models
fig, ax = plt.subplots(1, 2, figsize=(12, 4), sharex=True)
ax[0].plot(bkg_train_losses, label="Train")
ax[0].plot(bkg_val_losses, label="Validation")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].set_title("Background Flow Training")
ax[0].legend()

ax[1].plot(sig_train_losses, label="Train")
ax[1].plot(sig_val_losses, label="Validation")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Loss")
ax[1].set_title("Signal Flow Training")
ax[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpreting the density plot**
#
# The histogram shows the distribution of the likelihood ratio for signal (orange) and background (blue) events. Values greater than 1 mean the signal model assigns higher density than the background model for that event, but background events can still produce \(R>1\) because the two densities overlap in feature space. What matters is the relative separation of the two curves: the farther the orange curve sits to the right of the blue one, the easier it is to choose a threshold on \(R\) that keeps signal while rejecting background. The ROC curve below quantifies that separation across all thresholds.

# %%
# --- evaluate anomaly scores on held-out sample ---
with torch.no_grad():
    test_shifted_tensor = torch.from_numpy(SR_test_shifted.astype("float32")).to(device)
    sig_log_prob = model_S.log_prob(
        inputs=test_shifted_tensor[:, 1:-1],
        context=test_shifted_tensor[:, 0:1],
    ).cpu().numpy()

sig_prob = np.exp(sig_log_prob)
bg_prob = np.exp(log_B_test.flatten()) * mass_pdf_test
ratio = sig_prob / (bg_prob + 1e-12)

labels = SR_test[:, -1]

plt.figure(figsize=(7, 4))
plt.hist(ratio[labels == 0], bins=40, density=True, histtype='step', linewidth=2, color='tab:blue', label='Background')
plt.hist(ratio[labels == 1], bins=40, density=True, histtype='stepfilled', alpha=0.4, color='tab:orange', label='Signal')
plt.yscale("log")
plt.xlabel("R(x) = p_sig / p_bg")
plt.ylabel("Density")
plt.legend()
plt.title("Residual ANODE Anomaly Score")
plt.show()

signal_eff = (ratio[labels == 1] > 1.0).mean()
background_eff = (ratio[labels == 0] > 1.0).mean()
print(f"Signal efficiency at R>1: {signal_eff:.3f}")
print(f"Background efficiency at R>1: {background_eff:.3f}")

score_df = pd.DataFrame(
    {
        "time_ms": SR_test[:, 0],
        "label": labels,
        "sig_prob": sig_prob,
        "bg_prob": bg_prob,
        "anomaly_ratio": ratio,
    }
)
csv_path = project_root / "notebooks" / "anomaly_scores.csv"
score_df.to_csv(csv_path, index=False)
print(f"Saved anomaly scores to {csv_path}")
# Out:
# Signal efficiency at R>1: 1.000
# Background efficiency at R>1: 0.967
# Saved anomaly scores to /Users/krishwu/code/ranode/notebooks/anomaly_scores.csv

# %%
fpr, tpr, thresholds = roc_curve(labels, ratio)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], 'k--', alpha=0.6)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for R-Anode Score")
plt.legend(loc="lower right")
plt.grid(True, alpha=0.2)
plt.show()

# %%
# --- visualize strains vs time and distributions for data vs learned models ---
def sample_subset(data: np.ndarray, max_points: int = 600, rng: np.random.Generator = np.random.default_rng()):
    if len(data) <= max_points:
        return data
    idx = rng.choice(len(data), size=max_points, replace=False)
    return data[idx]

with torch.no_grad():
    cond_inputs = torch.from_numpy(SR_bkg_aligned_raw[:, 0].astype("float32")).reshape(-1, 1).to(device)
    bg_generated = model_B.model.sample(num_samples=cond_inputs.shape[0], cond_inputs=cond_inputs).cpu().numpy()
    sig_context = torch.from_numpy(SR_sig_shifted[:, 0:1].astype("float32")).to(device)
    generated = []
    for ctx in torch.split(sig_context, 1, dim=0):
        sample = model_S.sample(num_samples=1, context=ctx).cpu().numpy()
        if sample.ndim == 3:
            sample = sample[0, 0]
        elif sample.ndim == 2:
            sample = sample[0]
        generated.append(np.asarray(sample))
    sig_generated_features = np.stack(generated, axis=0)

bg_generated_full = np.concatenate([SR_bkg_aligned_raw[:, 0:1], bg_generated, np.zeros((bg_generated.shape[0], 1))], axis=1)
bg_generated_raw = inverse_transform(bg_generated_full, pre_params)

sig_time = sig_context.cpu().numpy() + center_time
sig_generated_features = np.atleast_2d(sig_generated_features)
sig_generated_processed = np.concatenate([sig_time, sig_generated_features, np.ones((sig_generated_features.shape[0], 1))], axis=1)
sig_generated_raw = inverse_transform(sig_generated_processed, pre_params)

plot_sets = {
    "Background Data": SR_bkg_aligned_raw,
    "Signal Data": SR_sig_aligned_raw,
    "Background Model": bg_generated_raw,
    "Signal Model": sig_generated_raw,
}

feature_names = [
    ("H_strain", 1),
    ("L_strain", 2),
    ("H+L", 3),
    ("H-L", 4),
 ]

rng = np.random.default_rng(2025)
for name, idx in feature_names:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    all_values = []
    for label, dataset in plot_sets.items():
        all_values.append(dataset[:, idx])
        subset = sample_subset(dataset, max_points=600, rng=rng)
        axes[0].scatter(subset[:, 0], subset[:, idx], label=label, s=10, alpha=0.5)
    axes[0].set_xlabel("Time [ms]")
    axes[0].set_ylabel(name)
    axes[0].set_title(f"{name} vs Time")
    axes[0].legend()

    values_concat = np.concatenate(all_values)
    vmin = np.quantile(values_concat, 0.01)
    vmax = np.quantile(values_concat, 0.99)
    bins = np.linspace(vmin, vmax, 60)

    for label, dataset in plot_sets.items():
        axes[1].hist(dataset[:, idx], bins=bins, histtype="step", density=True, label=label)

    axes[1].set_xlabel(name)
    axes[1].set_ylabel("Density")
    axes[1].set_title(f"{name} Distribution")
    axes[1].legend()
    plt.tight_layout()
    plt.show()
